# %%
from enum import Enum
import numpy as np
# from usefulFunctions import *
import copy
import  pickle

# %%
class Status(Enum):
    STAGED = 200
    ENQUEUED = 201
    DONE = 202

# %%
class Task:
    # __actionDict__ = {0:np.array([0,0]), 1:np.array([0,1]), 2:np.array([1,0]), 3:np.array([0,-1]), 4:np.array([-1,0])}
    __actionDict__ = {0:np.array([0,0]), 1:np.array([1,0]), 2:np.array([0,1]), 3:np.array([-1,0]), 4:np.array([0,-1])}

    def __init__(self, tid, rid, start, action, time) -> None:
        self.taskID = tid
        self.robotID = rid
        self.action = action
        self.startPos = np.array(start)
        self.goalPos = np.array(self.__actionDict__[action]+start)
        self.time = time
        self.preqs = dict()
        self.status = Status.STAGED
        
    def __checkIfReady__(self):
        # print("Check if ready", self.preqs)
        if self.taskID-1 not in self.preqs:
            temp = list(self.preqs.values())
            if(np.array_equal(temp, np.full_like(temp, Status.DONE.value))):
                return True
            else:
                return False
        if self.preqs[self.taskID-1]>=Status.ENQUEUED.value:
            temp = copy.deepcopy(self.preqs)
            del temp[self.taskID-1]
            temp = list(temp.values())
            if (np.array_equal(temp, np.full_like(temp, Status.DONE.value))):
                return True
            else:
                return False
        return False
    
    def __publishTask__(self):
        global TOPIC
        message = ROS_Task()
        message.taskID = self.taskID
        message.robotID = self.robotID
        message.action = self.action
        message.status = self.status.value

        TOPIC.publish(message)

    
    def __repr__(self) -> str:
        asd = "\n"
        for i in self.__dir__():
            if not i.startswith('__'):
                asd+=i
                asd+=": "
                asd+=str(getattr(self,i))
                asd+=", "

        return asd

class Graph:
    def __init__(self, taskList, startCells) -> None:
        self.currentPositions = copy.deepcopy(startCells)
        self.graph = dict()
        self.taskDict = dict()
        tId = 1
        self.robotList = []
        for rid in range(len(startCells)):
        
            prevTask = None
            for i, task in enumerate(taskList[:,rid]):
                t = Task(tId, rid, self.currentPositions[rid], task, i)
                # print(t)
                self.taskDict[tId] = t
                tId+=1
                self.currentPositions[rid] = t.goalPos
                self.addVertex(t)

                if(prevTask is None):
                    self.robotList.append(t)
                else:
                    self.addEdge(prevTask, t)

                prevTask = t
        # print(taskDict)
        for rid in range(len(startCells)):
            firstTid = self.robotList[rid].taskID
            for taskID in range(firstTid, firstTid+len(taskList)):
                if(taskID not in self.taskDict):
                    continue
                task = self.taskDict[taskID]
                
                for rid_ in range(len(startCells)):
                    if(rid != rid_):
                        # print(rid, rid_)
                        firstTid_ = self.robotList[rid_].taskID
                        for taskID_ in range(firstTid_, firstTid_+len(taskList)):
                            if(taskID_ not in self.taskDict):
                                continue
                            task_ = self.taskDict[taskID_]
                            if np.array_equal(task.startPos, task_.goalPos) and task.time<=task_.time:
                                # print(task, task_)
                                self.addEdge(task, task_)
                                break

            
    
    def addVertex(self, task):
        assert type(task) == Task
        if(task.taskID not in self.graph):
            self.graph[task.taskID] = list()

    def addEdge(self, taskFrom, taskTo):
        assert  type(taskFrom)==Task and taskFrom.taskID in self.graph
        assert type(taskTo)==Task and taskTo.taskID in self.graph
        taskTo.preqs[taskFrom.taskID] = taskFrom.status.value
        self.graph[taskFrom.taskID].append(taskTo.taskID)

    def changeStatus(self, taskID):
        # rospy.loginfo(taskID)
        task = self.taskDict[taskID]
        # print(taskID, task)
        task.status = Status(task.status.value+1)

        task.__publishTask__()

# %%
actionList= np.loadtxt('actions.txt')
actionList = actionList.astype(np.int16)
START=[(2, 7),(20, 1),(17, 16),(2, 0),(10, 1),(16, 22),(17, 7),(1, 4),(5, 5),(17, 18),(7, 22),(21, 20),(7, 1),(1, 2),(15, 21),(2, 17),(5, 10),(17, 13),(10, 22),(2, 21),(8, 4),(8, 19),(5, 3),(20, 3),(14, 12),(19, 20),(1, 7),(2, 14),(14, 21),(15, 2),(11, 21),(17, 1),(2, 10),(5, 9),(1, 5),(13, 1),(22, 2),(15, 14),(3, 21),(2, 8),(1, 0),(22, 16),(0, 14),(21, 2),(8, 22),(18, 8),(18, 1),(0, 20),(1, 22),(17, 5),(11, 8),(17, 11),(8, 17),(0, 9),(16, 0),(17, 2),(4, 8),(14, 19),(2, 11),(12, 14),(8, 6),(21, 1),(2, 16),(21, 17),(0, 18),(19, 22),(20, 16),(9, 2),(0, 17),(7, 8),(1, 6),(11, 0),(17, 3),(0, 0),(9, 14),(22, 10),(8, 9),(21, 16),(21, 15),(1, 1),(20, 15),(19, 1),(9, 22),(22, 3),(2, 9),(7, 21),(14, 13),(0, 21),(12, 8),(0, 2),(18, 20),(17, 22),(1, 10),(0, 10),(5, 4),(22, 5),(13, 8),(2, 22),(5, 15),(6, 14),(1, 13),(5, 19),(22, 7),(0, 12),(15, 22),(21, 19),(5, 20),(10, 8),(21, 7),(22, 0),(7, 2),(1, 16),(11, 19),(14, 8),(8, 5),(1, 19),(1, 11),(0, 5),(1, 20),(8, 7),(5, 18),(14, 6),(22, 21),(14, 17),(6, 2),(18, 14),(15, 20),(12, 22),(21, 12),(6, 8),(0, 7),(11, 17),(22, 20),(0, 11),(11, 6),(14, 2),(2, 3),(16, 2),(14, 10),(0, 13),(16, 1),(15, 1),(21, 21),(18, 21),(0, 4),(5, 22),(20, 6),(1, 9),(20, 14),(12, 0),(0, 8),(20, 5),(20, 13),(12, 2),(13, 22),(1, 3),(21, 10),(11, 3),(4, 1),(17, 21),(20, 18),(14, 3),(14, 14),(0, 6),(7, 14),(22, 8),(8, 1),(2, 19),(12, 1),(20, 4),(18, 0),(1, 17),(5, 1),(22, 18),(19, 0),(22, 9),(9, 8),(17, 17),(2, 12),(21, 8),(8, 21),(20, 19),(5, 11),(17, 10),(17, 6),(22, 14),(3, 20),(11, 15),(3, 2),(8, 3),(17, 15),(13, 21),(18, 22),(14, 1),(21, 3),(6, 0),(8, 8),(14, 11),(21, 13),(11, 1),(10, 20),(22, 13),(5, 13),(6, 21),(0, 22),(3, 22),(0, 16),(3, 14),(4, 14),(1, 15),(5, 14),(8, 15)]
START = START[:30]
actionList = actionList[:,:30]

# %%
GRAPH = Graph(actionList, START)

# %%
class GraphTD:
    def __init__(self, taskList, startCells) -> None:
        positions = {}
        self.currentPositions = copy.deepcopy(startCells)

        self.graph = dict()
        self.taskDict = dict()
        tId = 1
        self.robotList = []
        for rid in range(len(startCells)):
        
            prevTask = None
            for i, task in enumerate(taskList[:,rid]):

                # print(tId, rid, currentPositions[rid], task, i)
                t = Task(tId, rid, self.currentPositions[rid], task, i)
                # print(t)
                self.taskDict[tId] = t
                tId+=1
                self.currentPositions[rid] = t.goalPos
                self.addVertex(t)

                if(tuple(t.goalPos) not in positions):
                    positions[tuple(t.goalPos)] = dict()
                positions[tuple(t.goalPos)][t.time] = t.taskID

                if(prevTask is None):
                    self.robotList.append(t)
                else:
                    self.addEdge(prevTask, t)

                prevTask = t
        # print(self.taskDict)

        # self.pos = positions
        for pos in positions:
            timeList = sorted(positions[pos].keys())
            # print(timeList)
            # print(positions[pos][0])
            for i in range(len(timeList)):
                for j in range(i+1, len(timeList)):
                    # print(positions[pos], positions[pos][timeList[i]], positions[pos][timeList[j]])
                    self.addEdge(self.taskDict[positions[pos][timeList[i]]+1], self.taskDict[positions[pos][timeList[j]]])

        for t in range(1, len(self.taskDict), len(taskList)):
            # print(self.taskDict[t])
            if(tuple(self.taskDict[t].startPos) in positions):
                for time in positions[tuple(self.taskDict[t].startPos)]:
                    self.addEdge(self.taskDict[t], self.taskDict[positions[tuple(self.taskDict[t].startPos)][time]])



        for rid in range(len(startCells)):
            firstTid = self.robotList[rid].taskID
            for taskID in range(firstTid, firstTid+len(taskList)):
                if(taskID not in self.taskDict):
                    continue
                task = self.taskDict[taskID]
                
        #         for rid_ in range(len(startCells)):
        #             if(rid == rid_):
        #                 continue
        #             else:
        #                 firstTid_ = self.robotList[rid_].taskID
        #                 for taskID_ in range(firstTid_, firstTid_+len(taskList)):
        #                     if(taskID_ not in self.taskDict):
        #                         continue
        #                     task_ = self.taskDict[taskID_]
        #                     if np.array_equal(task.startPos, task_.goalPos) and task.time<=task_.time:
        #                         self.addEdge(task, task_)
        #                         break

            
    
    def addVertex(self, task):
        assert type(task) == Task
        if(task.taskID not in self.graph):
            self.graph[task.taskID] = list()


    def addEdge(self, taskFrom, taskTo):
        assert  type(taskFrom)==Task and taskFrom.taskID in self.graph
        assert type(taskTo)==Task and taskTo.taskID in self.graph

        if(taskFrom.taskID in taskTo.preqs or taskFrom.taskID==taskTo.taskID):
            return
        for t in self.graph[taskFrom.taskID]:
            if(self.taskDict[t].robotID==taskTo.robotID):
                return


        taskTo.preqs[taskFrom.taskID] = taskFrom.status.value
        self.graph[taskFrom.taskID].append(taskTo.taskID)

    def changeStatus(self, taskID):
        # rospy.loginfo(taskID)
        task = self.taskDict[taskID]
        # print(taskID, task)
        task.status = Status(task.status.value+1)

        task.__publishTask__()

# %%
G2 = GraphTD(actionList, START)
# G2.taskDict

# %%
asd = G2.currentPositions
GOALS = [(9, 0),(0, 19),(11, 2),(0, 6),(5, 0),(11, 4),(8, 6),(14, 21),(22, 3),(11, 14),(20, 14),(0, 5),(15, 8),(17, 12),(0, 0),(19, 14),(1, 22),(0, 11),(3, 8),(22, 15),(5, 22),(21, 8),(17, 11),(3, 21),(5, 12),(14, 1),(17, 6),(5, 4),(1, 19),(17, 18),(14, 13),(17, 0),(2, 21),(11, 11),(4, 21),(5, 13),(11, 5),(11, 9),(8, 4),(20, 2),(16, 2),(17, 16),(5, 17),(0, 8),(8, 16),(6, 1),(14, 20),(22, 6),(22, 1),(4, 22),(5, 14),(6, 8),(20, 8),(11, 16),(22, 13),(0, 22),(11, 20),(20, 18),(17, 5),(10, 20),(22, 22),(22, 0),(8, 8),(5, 10),(21, 16),(22, 12),(17, 9),(12, 1),(21, 5),(14, 2),(22, 2),(13, 0),(8, 18),(21, 6),(21, 0),(20, 9),(10, 22),(21, 1),(20, 22),(10, 1),(12, 8),(7, 8),(0, 10),(13, 21),(1, 3),(8, 13),(22, 17),(21, 2),(18, 8),(11, 8),(17, 2),(18, 1),(19, 21),(19, 22),(5, 5),(15, 0),(10, 21),(16, 20),(5, 21),(8, 5),(13, 8),(0, 15),(22, 8),(13, 20),(21, 3),(2, 12),(22, 20),(5, 19),(10, 8),(4, 0),(1, 9),(16, 22),(2, 0),(5, 1),(5, 16),(15, 20),(0, 12),(0, 1),(21, 21),(14, 18),(2, 1),(14, 4),(14, 5),(1, 17),(17, 13),(6, 14),(18, 0),(17, 3),(10, 2),(2, 13),(22, 21),(4, 1),(1, 20),(17, 21),(0, 17),(20, 6),(1, 2),(4, 8),(14, 9),(14, 10),(5, 20),(14, 11),(14, 22),(3, 22),(22, 9),(12, 2),(11, 1),(22, 7),(4, 14),(22, 14),(0, 13),(17, 22),(0, 3),(20, 21),(2, 7),(1, 8),(21, 14),(11, 13),(10, 0),(15, 1),(11, 19),(22, 11),(11, 18),(6, 2),(19, 1),(21, 4),(0, 4),(3, 2),(18, 20),(5, 6),(15, 21),(20, 0),(1, 14),(2, 15),(21, 19),(20, 11),(11, 22),(17, 19),(16, 0),(22, 10),(4, 20),(13, 1),(20, 16),(22, 4),(8, 12),(9, 21),(8, 1),(7, 14),(12, 21),(17, 7),(8, 2),(2, 4),(14, 8),(20, 1),(21, 11),(3, 1),(18, 2),(9, 8),(5, 7),(21, 17),(8, 0),(0, 18),(8, 20),(2, 14),(8, 14),(1, 21),(0, 14),(1, 13),(2, 19),(1, 16),(6, 21),(1, 18)]
GOALS = GOALS[:6]

for i in range(len(GOALS)):
    if(np.array_equal(asd[i], GOALS[i])):
        pass
    else:
        print(False)

# %%
for i in GRAPH.graph:
    if not (np.array_equal(set(GRAPH.graph[i]), set(G2.graph[i]))):
        print(i, GRAPH.graph[i], G2.graph[i])
    for j in GRAPH.graph[i]:
        if(j not in G2.graph[i]):
            print("False")

# %%
for i in G2.graph:
    G2.graph[i] = sorted(G2.graph[i])

for i in GRAPH.graph:
    GRAPH.graph[i] = sorted(GRAPH.graph[i])

# %%
for i in G2.taskDict:
    if not(G2.taskDict[i].action == GRAPH.taskDict[i].action):
        print(False)

# %%
i = 3
for j in G2.graph[i]:
    print(j)
    if(j not in GRAPH.graph[i]):
        
        print("False")
# Out:
# 4
# 1696

# %%
for i in G2.graph:
    # print(set(GRAPH.graph[i]), set(G2.graph[i]))
    if not (np.array_equal(set(GRAPH.graph[i]), set(G2.graph[i]))):
        print(i, GRAPH.graph[i], G2.graph[i])
    for j in G2.graph[i]:
        if(j not in GRAPH.graph[i]):
            print("False")

# %%
# import json 
# with open("/media/marmot-18/Thordak2TB/catkin_ws/src/Tanishq_MAPF/database/pickle_test.txt", "w") as f:
#     f.write(json.dumps(GRAPH.graph))

# %%
# import json 
# with open("/media/marmot-18/Thordak2TB/catkin_ws/src/Tanishq_MAPF/database/TD_test.txt", "w") as f:
#     f.write(json.dumps(G2.graph))

# %%
# with open("/media/marmot-18/Thordak2TB/catkin_ws/src/Tanishq_MAPF/database/pickle_test.obj", "r") as f:
#     G3 = pickle.load(f)

temp = {}
for i in GRAPH.graph:
    temp[i] = {}
    for j in dir(GRAPH.taskDict[i]):
        # print(j)
        if not j.startswith("__"):
            temp[i][j] = getattr(GRAPH.taskDict[i], j)

# %%
temp
# Out:
# {1: {'action': 0,
#   'goalPos': array([2, 7]),
#   'preqs': {},
#   'robotID': 0,
#   'startPos': array([2, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 1,
#   'time': 0},
#  2: {'action': 0,
#   'goalPos': array([2, 7]),
#   'preqs': {1: 200},
#   'robotID': 0,
#   'startPos': array([2, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 2,
#   'time': 1},
#  3: {'action': 3,
#   'goalPos': array([1, 7]),
#   'preqs': {2: 200, 1613: 200},
#   'robotID': 0,
#   'startPos': array([2, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 3,
#   'time': 2},
#  4: {'action': 0,
#   'goalPos': array([1, 7]),
#   'preqs': {3: 200},
#   'robotID': 0,
#   'startPos': array([1, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 4,
#   'time': 3},
#  5: {'action': 0,
#   'goalPos': array([1, 7]),
#   'preqs': {4: 200},
#   'robotID': 0,
#   'startPos': array([1, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 5,
#   'time': 4},
#  6: {'action': 0,
#   'goalPos': array([1, 7]),
#   'preqs': {5: 200},
#   'robotID': 0,
#   'startPos': array([1, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 6,
#   'time': 5},
#  7: {'action': 0,
#   'goalPos': array([1, 7]),
#   'preqs': {6: 200},
#   'robotID': 0,
#   'startPos': array([1, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 7,
#   'time': 6},
#  8: {'action': 2,
#   'goalPos': array([1, 8]),
#   'preqs': {7: 200},
#   'robotID': 0,
#   'startPos': array([1, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 8,
#   'time': 7},
#  9: {'action': 1,
#   'goalPos': array([2, 8]),
#   'preqs': {8: 200},
#   'robotID': 0,
#   'startPos': array([1, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 9,
#   'time': 8},
#  10: {'action': 0,
#   'goalPos': array([2, 8]),
#   'preqs': {9: 200},
#   'robotID': 0,
#   'startPos': array([2, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 10,
#   'time': 9},
#  11: {'action': 0,
#   'goalPos': array([2, 8]),
#   'preqs': {10: 200},
#   'robotID': 0,
#   'startPos': array([2, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 11,
#   'time': 10},
#  12: {'action': 3,
#   'goalPos': array([1, 8]),
#   'preqs': {11: 200},
#   'robotID': 0,
#   'startPos': array([2, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 12,
#   'time': 11},
#  13: {'action': 1,
#   'goalPos': array([2, 8]),
#   'preqs': {12: 200},
#   'robotID': 0,
#   'startPos': array([1, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 13,
#   'time': 12},
#  14: {'action': 4,
#   'goalPos': array([2, 7]),
#   'preqs': {13: 200},
#   'robotID': 0,
#   'startPos': array([2, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 14,
#   'time': 13},
#  15: {'action': 4,
#   'goalPos': array([2, 6]),
#   'preqs': {14: 200},
#   'robotID': 0,
#   'startPos': array([2, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 15,
#   'time': 14},
#  16: {'action': 4,
#   'goalPos': array([2, 5]),
#   'preqs': {15: 200},
#   'robotID': 0,
#   'startPos': array([2, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 16,
#   'time': 15},
#  17: {'action': 4,
#   'goalPos': array([2, 4]),
#   'preqs': {16: 200, 1617: 200},
#   'robotID': 0,
#   'startPos': array([2, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 17,
#   'time': 16},
#  18: {'action': 0,
#   'goalPos': array([2, 4]),
#   'preqs': {17: 200},
#   'robotID': 0,
#   'startPos': array([2, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 18,
#   'time': 17},
#  19: {'action': 4,
#   'goalPos': array([2, 3]),
#   'preqs': {18: 200, 437: 200, 1618: 200},
#   'robotID': 0,
#   'startPos': array([2, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 19,
#   'time': 18},
#  20: {'action': 3,
#   'goalPos': array([1, 3]),
#   'preqs': {19: 200, 436: 200},
#   'robotID': 0,
#   'startPos': array([2, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 20,
#   'time': 19},
#  21: {'action': 4,
#   'goalPos': array([1, 2]),
#   'preqs': {20: 200,
#    807: 200,
#    808: 200,
#    809: 200,
#    810: 200,
#    811: 200,
#    812: 200,
#    813: 200},
#   'robotID': 0,
#   'startPos': array([1, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 21,
#   'time': 20},
#  22: {'action': 0,
#   'goalPos': array([1, 2]),
#   'preqs': {21: 200},
#   'robotID': 0,
#   'startPos': array([1, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 22,
#   'time': 21},
#  23: {'action': 1,
#   'goalPos': array([2, 2]),
#   'preqs': {22: 200, 438: 200, 814: 200, 1619: 200},
#   'robotID': 0,
#   'startPos': array([1, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 23,
#   'time': 22},
#  24: {'action': 1,
#   'goalPos': array([3, 2]),
#   'preqs': {23: 200, 439: 200, 815: 200, 1620: 200},
#   'robotID': 0,
#   'startPos': array([2, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 24,
#   'time': 23},
#  25: {'action': 1,
#   'goalPos': array([4, 2]),
#   'preqs': {24: 200, 440: 200, 816: 200, 817: 200, 1621: 200},
#   'robotID': 0,
#   'startPos': array([3, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 25,
#   'time': 24},
#  26: {'action': 4,
#   'goalPos': array([4, 1]),
#   'preqs': {25: 200},
#   'robotID': 0,
#   'startPos': array([4, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 26,
#   'time': 25},
#  27: {'action': 4,
#   'goalPos': array([4, 0]),
#   'preqs': {26: 200},
#   'robotID': 0,
#   'startPos': array([4, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 27,
#   'time': 26},
#  28: {'action': 1,
#   'goalPos': array([5, 0]),
#   'preqs': {27: 200, 1368: 200},
#   'robotID': 0,
#   'startPos': array([4, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 28,
#   'time': 27},
#  29: {'action': 1,
#   'goalPos': array([6, 0]),
#   'preqs': {28: 200, 80: 200},
#   'robotID': 0,
#   'startPos': array([5, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 29,
#   'time': 28},
#  30: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {29: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 30,
#   'time': 29},
#  31: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {30: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 31,
#   'time': 30},
#  32: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {31: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 32,
#   'time': 31},
#  33: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {32: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 33,
#   'time': 32},
#  34: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {33: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 34,
#   'time': 33},
#  35: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {34: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 35,
#   'time': 34},
#  36: {'action': 1,
#   'goalPos': array([7, 0]),
#   'preqs': {35: 200, 79: 200, 263: 200, 264: 200, 270: 200, 746: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 36,
#   'time': 35},
#  37: {'action': 1,
#   'goalPos': array([8, 0]),
#   'preqs': {36: 200,
#    78: 200,
#    260: 200,
#    261: 200,
#    262: 200,
#    271: 200,
#    747: 200},
#   'robotID': 0,
#   'startPos': array([7, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 37,
#   'time': 36},
#  38: {'action': 1,
#   'goalPos': array([9, 0]),
#   'preqs': {37: 200, 77: 200, 1629: 200, 1630: 200, 1631: 200, 1632: 200},
#   'robotID': 0,
#   'startPos': array([8, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 38,
#   'time': 37},
#  39: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {38: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 39,
#   'time': 38},
#  40: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {39: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 40,
#   'time': 39},
#  41: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {40: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 41,
#   'time': 40},
#  42: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {41: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 42,
#   'time': 41},
#  43: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {42: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 43,
#   'time': 42},
#  44: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {43: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 44,
#   'time': 43},
#  45: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {44: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 45,
#   'time': 44},
#  46: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {45: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 46,
#   'time': 45},
#  47: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {46: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 47,
#   'time': 46},
#  48: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {47: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 48,
#   'time': 47},
#  49: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {48: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 49,
#   'time': 48},
#  50: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {49: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 50,
#   'time': 49},
#  51: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {50: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 51,
#   'time': 50},
#  52: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {51: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 52,
#   'time': 51},
#  53: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {52: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 53,
#   'time': 52},
#  54: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {53: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 54,
#   'time': 53},
#  55: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {54: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 55,
#   'time': 54},
#  56: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {55: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 56,
#   'time': 55},
#  57: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {56: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 57,
#   'time': 56},
#  58: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {57: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 58,
#   'time': 57},
#  59: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {58: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 59,
#   'time': 58},
#  60: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {59: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 60,
#   'time': 59},
#  61: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {60: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 61,
#   'time': 60},
#  62: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {61: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 62,
#   'time': 61},
#  63: {'action': 4,
#   'goalPos': array([20,  0]),
#   'preqs': {},
#   'robotID': 1,
#   'startPos': array([20,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 63,
#   'time': 0},
#  64: {'action': 3,
#   'goalPos': array([19,  0]),
#   'preqs': {63: 200},
#   'robotID': 1,
#   'startPos': array([20,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 64,
#   'time': 1},
#  65: {'action': 3,
#   'goalPos': array([18,  0]),
#   'preqs': {64: 200},
#   'robotID': 1,
#   'startPos': array([19,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 65,
#   'time': 2},
#  66: {'action': 2,
#   'goalPos': array([18,  1]),
#   'preqs': {65: 200},
#   'robotID': 1,
#   'startPos': array([18,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 66,
#   'time': 3},
#  67: {'action': 3,
#   'goalPos': array([17,  1]),
#   'preqs': {66: 200},
#   'robotID': 1,
#   'startPos': array([18,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 67,
#   'time': 4},
#  68: {'action': 3,
#   'goalPos': array([16,  1]),
#   'preqs': {67: 200, 1802: 200},
#   'robotID': 1,
#   'startPos': array([17,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 68,
#   'time': 5},
#  69: {'action': 3,
#   'goalPos': array([15,  1]),
#   'preqs': {68: 200},
#   'robotID': 1,
#   'startPos': array([16,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 69,
#   'time': 6},
#  70: {'action': 4,
#   'goalPos': array([15,  0]),
#   'preqs': {69: 200},
#   'robotID': 1,
#   'startPos': array([15,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 70,
#   'time': 7},
#  71: {'action': 3,
#   'goalPos': array([14,  0]),
#   'preqs': {70: 200},
#   'robotID': 1,
#   'startPos': array([15,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 71,
#   'time': 8},
#  72: {'action': 3,
#   'goalPos': array([13,  0]),
#   'preqs': {71: 200},
#   'robotID': 1,
#   'startPos': array([14,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 72,
#   'time': 9},
#  73: {'action': 3,
#   'goalPos': array([12,  0]),
#   'preqs': {72: 200},
#   'robotID': 1,
#   'startPos': array([13,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 73,
#   'time': 10},
#  74: {'action': 3,
#   'goalPos': array([11,  0]),
#   'preqs': {73: 200},
#   'robotID': 1,
#   'startPos': array([12,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 74,
#   'time': 11},
#  75: {'action': 3,
#   'goalPos': array([10,  0]),
#   'preqs': {74: 200},
#   'robotID': 1,
#   'startPos': array([11,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 75,
#   'time': 12},
#  76: {'action': 3,
#   'goalPos': array([9, 0]),
#   'preqs': {75: 200},
#   'robotID': 1,
#   'startPos': array([10,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 76,
#   'time': 13},
#  77: {'action': 3,
#   'goalPos': array([8, 0]),
#   'preqs': {76: 200, 260: 200, 261: 200, 262: 200, 747: 200},
#   'robotID': 1,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 77,
#   'time': 14},
#  78: {'action': 3,
#   'goalPos': array([7, 0]),
#   'preqs': {77: 200, 263: 200, 264: 200, 746: 200},
#   'robotID': 1,
#   'startPos': array([8, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 78,
#   'time': 15},
#  79: {'action': 3,
#   'goalPos': array([6, 0]),
#   'preqs': {78: 200},
#   'robotID': 1,
#   'startPos': array([7, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 79,
#   'time': 16},
#  80: {'action': 2,
#   'goalPos': array([6, 1]),
#   'preqs': {79: 200, 1373: 200, 1625: 200},
#   'robotID': 1,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 80,
#   'time': 17},
#  81: {'action': 3,
#   'goalPos': array([5, 1]),
#   'preqs': {80: 200, 1367: 200, 1369: 200, 1374: 200},
#   'robotID': 1,
#   'startPos': array([6, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 81,
#   'time': 18},
#  82: {'action': 2,
#   'goalPos': array([5, 2]),
#   'preqs': {81: 200,
#    441: 200,
#    500: 200,
#    818: 200,
#    1366: 200,
#    1370: 200,
#    1375: 200,
#    1622: 200},
#   'robotID': 1,
#   'startPos': array([5, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 82,
#   'time': 19},
#  83: {'action': 2,
#   'goalPos': array([5, 3]),
#   'preqs': {82: 200, 442: 200, 499: 200, 1365: 200, 1376: 200},
#   'robotID': 1,
#   'startPos': array([5, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 83,
#   'time': 20},
#  84: {'action': 2,
#   'goalPos': array([5, 4]),
#   'preqs': {83: 200, 443: 200, 498: 200, 1377: 200},
#   'robotID': 1,
#   'startPos': array([5, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 84,
#   'time': 21},
#  85: {'action': 2,
#   'goalPos': array([5, 5]),
#   'preqs': {84: 200, 444: 200, 497: 200, 1378: 200},
#   'robotID': 1,
#   'startPos': array([5, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 85,
#   'time': 22},
#  86: {'action': 2,
#   'goalPos': array([5, 6]),
#   'preqs': {85: 200, 445: 200, 1379: 200},
#   'robotID': 1,
#   'startPos': array([5, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 86,
#   'time': 23},
#  87: {'action': 2,
#   'goalPos': array([5, 7]),
#   'preqs': {86: 200, 446: 200, 447: 200, 1380: 200},
#   'robotID': 1,
#   'startPos': array([5, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 87,
#   'time': 24},
#  88: {'action': 2,
#   'goalPos': array([5, 8]),
#   'preqs': {87: 200, 448: 200, 1381: 200},
#   'robotID': 1,
#   'startPos': array([5, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 88,
#   'time': 25},
#  89: {'action': 2,
#   'goalPos': array([5, 9]),
#   'preqs': {88: 200},
#   'robotID': 1,
#   'startPos': array([5, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 89,
#   'time': 26},
#  90: {'action': 2,
#   'goalPos': array([ 5, 10]),
#   'preqs': {89: 200, 993: 200},
#   'robotID': 1,
#   'startPos': array([5, 9]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 90,
#   'time': 27},
#  91: {'action': 2,
#   'goalPos': array([ 5, 11]),
#   'preqs': {90: 200, 994: 200},
#   'robotID': 1,
#   'startPos': array([ 5, 10]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 91,
#   'time': 28},
#  92: {'action': 2,
#   'goalPos': array([ 5, 12]),
#   'preqs': {91: 200, 995: 200},
#   'robotID': 1,
#   'startPos': array([ 5, 11]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 92,
#   'time': 29},
#  93: {'action': 2,
#   'goalPos': array([ 5, 13]),
#   'preqs': {92: 200, 996: 200},
#   'robotID': 1,
#   'startPos': array([ 5, 12]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 93,
#   'time': 30},
#  94: {'action': 2,
#   'goalPos': array([ 5, 14]),
#   'preqs': {93: 200, 950: 200, 956: 200, 997: 200, 1075: 200},
#   'robotID': 1,
#   'startPos': array([ 5, 13]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 94,
#   'time': 31},
#  95: {'action': 3,
#   'goalPos': array([ 4, 14]),
#   'preqs': {94: 200, 949: 200, 1076: 200},
#   'robotID': 1,
#   'startPos': array([ 5, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 95,
#   'time': 32},
#  96: {'action': 3,
#   'goalPos': array([ 3, 14]),
#   'preqs': {95: 200, 947: 200, 948: 200, 1077: 200},
#   'robotID': 1,
#   'startPos': array([ 4, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 96,
#   'time': 33},
#  97: {'action': 3,
#   'goalPos': array([ 2, 14]),
#   'preqs': {96: 200, 946: 200, 1078: 200, 1675: 200},
#   'robotID': 1,
#   'startPos': array([ 3, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 97,
#   'time': 34},
#  98: {'action': 2,
#   'goalPos': array([ 2, 15]),
#   'preqs': {97: 200, 942: 200, 943: 200, 944: 200, 945: 200},
#   'robotID': 1,
#   'startPos': array([ 2, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 98,
#   'time': 35},
#  99: {'action': 3,
#   'goalPos': array([ 1, 15]),
#   'preqs': {98: 200, 939: 200, 940: 200, 941: 200},
#   'robotID': 1,
#   'startPos': array([ 2, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 99,
#   'time': 36},
#  100: {'action': 2,
#   'goalPos': array([ 1, 16]),
#   'preqs': {99: 200, 937: 200, 938: 200},
#   'robotID': 1,
#   'startPos': array([ 1, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 100,
#   'time': 37},
#  101: {'action': 3,
#   'goalPos': array([ 0, 16]),
#   'preqs': {100: 200, 712: 200, 895: 200, 1141: 200},
#   'robotID': 1,
#   'startPos': array([ 1, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 101,
#   'time': 38},
#  102: {'action': 2,
#   'goalPos': array([ 0, 17]),
#   'preqs': {101: 200, 711: 200, 894: 200, 1140: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 102,
#   'time': 39},
#  103: {'action': 2,
#   'goalPos': array([ 0, 18]),
#   'preqs': {102: 200, 710: 200, 893: 200, 1139: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 103,
#   'time': 40},
#  104: {'action': 2,
#   'goalPos': array([ 0, 19]),
#   'preqs': {103: 200, 709: 200, 892: 200, 1138: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 18]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 104,
#   'time': 41},
#  105: {'action': 2,
#   'goalPos': array([ 0, 20]),
#   'preqs': {104: 200, 708: 200, 891: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 105,
#   'time': 42},
#  106: {'action': 2,
#   'goalPos': array([ 0, 21]),
#   'preqs': {105: 200, 890: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 20]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 106,
#   'time': 43},
#  107: {'action': 0,
#   'goalPos': array([ 0, 21]),
#   'preqs': {106: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 21]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 107,
#   'time': 44},
#  108: {'action': 4,
#   'goalPos': array([ 0, 20]),
#   'preqs': {107: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 21]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 108,
#   'time': 45},
#  109: {'action': 4,
#   'goalPos': array([ 0, 19]),
#   'preqs': {108: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 20]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 109,
#   'time': 46},
#  110: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {109: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 110,
#   'time': 47},
#  111: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {110: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 111,
#   'time': 48},
#  112: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {111: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 112,
#   'time': 49},
#  113: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {112: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 113,
#   'time': 50},
#  114: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {113: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 114,
#   'time': 51},
#  115: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {114: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 115,
#   'time': 52},
#  116: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {115: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 116,
#   'time': 53},
#  117: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {116: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 117,
#   'time': 54},
#  118: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {117: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 118,
#   'time': 55},
#  119: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {118: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 119,
#   'time': 56},
#  120: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {119: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 120,
#   'time': 57},
#  121: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {120: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 121,
#   'time': 58},
#  122: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {121: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 122,
#   'time': 59},
#  123: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {122: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 123,
#   'time': 60},
#  124: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {123: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 124,
#   'time': 61},
#  125: {'action': 4,
#   'goalPos': array([17, 15]),
#   'preqs': {},
#   'robotID': 2,
#   'startPos': array([17, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 125,
#   'time': 0},
#  126: {'action': 0,
#   'goalPos': array([17, 15]),
#   'preqs': {125: 200},
#   'robotID': 2,
#   'startPos': array([17, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 126,
#   'time': 1},
#  127: {'action': 0,
#   'goalPos': array([17, 15]),
#   'preqs': {126: 200},
#   'robotID': 2,
#   'startPos': array([17, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 127,
#   'time': 2},
#  128: {'action': 4,
#   'goalPos': array([17, 14]),
#   'preqs': {127: 200, 1057: 200},
#   'robotID': 2,
#   'startPos': array([17, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 128,
#   'time': 3},
#  129: {'action': 3,
#   'goalPos': array([16, 14]),
#   'preqs': {128: 200, 1058: 200},
#   'robotID': 2,
#   'startPos': array([17, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 129,
#   'time': 4},
#  130: {'action': 3,
#   'goalPos': array([15, 14]),
#   'preqs': {129: 200, 1059: 200},
#   'robotID': 2,
#   'startPos': array([16, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 130,
#   'time': 5},
#  131: {'action': 3,
#   'goalPos': array([14, 14]),
#   'preqs': {130: 200, 1060: 200},
#   'robotID': 2,
#   'startPos': array([15, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 131,
#   'time': 6},
#  132: {'action': 4,
#   'goalPos': array([14, 13]),
#   'preqs': {131: 200},
#   'robotID': 2,
#   'startPos': array([14, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 132,
#   'time': 7},
#  133: {'action': 4,
#   'goalPos': array([14, 12]),
#   'preqs': {132: 200, 1489: 200},
#   'robotID': 2,
#   'startPos': array([14, 13]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 133,
#   'time': 8},
#  134: {'action': 4,
#   'goalPos': array([14, 11]),
#   'preqs': {133: 200, 1490: 200, 1491: 200},
#   'robotID': 2,
#   'startPos': array([14, 12]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 134,
#   'time': 9},
#  135: {'action': 4,
#   'goalPos': array([14, 10]),
#   'preqs': {134: 200, 1492: 200},
#   'robotID': 2,
#   'startPos': array([14, 11]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 135,
#   'time': 10},
#  136: {'action': 4,
#   'goalPos': array([14,  9]),
#   'preqs': {135: 200, 1493: 200},
#   'robotID': 2,
#   'startPos': array([14, 10]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 136,
#   'time': 11},
#  137: {'action': 4,
#   'goalPos': array([14,  8]),
#   'preqs': {136: 200, 1494: 200},
#   'robotID': 2,
#   'startPos': array([14,  9]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 137,
#   'time': 12},
#  138: {'action': 1,
#   'goalPos': array([15,  8]),
#   'preqs': {137: 200},
#   'robotID': 2,
#   'startPos': array([14,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 138,
#   'time': 13},
#  139: {'action': 0,
#   'goalPos': array([15,  8]),
#   'preqs': {138: 200},
#   'robotID': 2,
#   'startPos': array([15,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 139,
#   'time': 14},
#  140: {'action': 0,
#   'goalPos': array([15,  8]),
#   'preqs': {139: 200},
#   'robotID': 2,
#   'startPos': array([15,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 140,
#   'time': 15},
#  141: {'action': 0,
#   'goalPos': array([15,  8]),
#   'preqs': {140: 200},
#   'robotID': 2,
#   'startPos': array([15,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 141,
#   'time': 16},
#  142: {'action': 3,
#   'goalPos': array([14,  8]),
#   'preqs': {141: 200, 1504: 200},
#   'robotID': 2,
#   'startPos': array([15,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 142,
#   'time': 17},
#  143: {'action': 4,
#   'goalPos': array([14,  7]),
#   'preqs': {142: 200,
#    1495: 200,
#    1496: 200,
#    1497: 200,
#    1498: 200,
#    1499: 200,
#    1500: 200,
#    1501: 200,
#    1502: 200,
#    1503: 200},
#   'robotID': 2,
#   'startPos': array([14,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 143,
#   'time': 18},
#  144: {'action': 4,
#   'goalPos': array([14,  6]),
#   'preqs': {143: 200},
#   'robotID': 2,
#   'startPos': array([14,  7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 144,
#   'time': 19},
#  145: {'action': 4,
#   'goalPos': array([14,  5]),
#   'preqs': {144: 200},
#   'robotID': 2,
#   'startPos': array([14,  6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 145,
#   'time': 20},
#  146: {'action': 4,
#   'goalPos': array([14,  4]),
#   'preqs': {145: 200},
#   'robotID': 2,
#   'startPos': array([14,  5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 146,
#   'time': 21},
#  147: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {146: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 147,
#   'time': 22},
#  148: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {147: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 148,
#   'time': 23},
#  149: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {148: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 149,
#   'time': 24},
#  150: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {149: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 150,
#   'time': 25},
#  151: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {150: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 151,
#   'time': 26},
#  152: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {151: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 152,
#   'time': 27},
#  153: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {152: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 153,
#   'time': 28},
#  154: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {153: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 154,
#   'time': 29},
#  155: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {154: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 155,
#   'time': 30},
#  156: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {155: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 156,
#   'time': 31},
#  157: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {156: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 157,
#   'time': 32},
#  158: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {157: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 158,
#   'time': 33},
#  159: {'action': 4,
#   'goalPos': array([14,  3]),
#   'preqs': {158: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 159,
#   'time': 34},
#  160: {'action': 4,
#   'goalPos': array([14,  2]),
#   'preqs': {159: 200, 404: 200, 514: 200, 757: 200, 760: 200},
#   'robotID': 2,
#   'startPos': array([14,  3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 160,
#   'time': 35},
#  161: {'action': 0,
#   'goalPos': array([14,  2]),
#   'preqs': {160: 200},
#   'robotID': 2,
#   'startPos': array([14,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 161,
#   'time': 36},
#  162: {'action': 3,
#   'goalPos': array([13,  2]),
#   'preqs': {161: 200, 405: 200, 513: 200, 756: 200},
#   'robotID': 2,
#   'startPos': array([14,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 162,
#   'time': 37},
#  163: {'action': 3,
#   'goalPos': array([12,  2]),
#   'preqs': {162: 200, 406: 200, 511: 200, 512: 200, 755: 200},
#   'robotID': 2,
#   'startPos': array([13,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 163,
#   'time': 38},
#  164: {'action': 3,
#   'goalPos': array([11,  2]),
#   'preqs': {163: 200, 407: 200, 510: 200, 754: 200, 828: 200, 1246: 200},
#   'robotID': 2,
#   'startPos': array([12,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 164,
#   'time': 39},
#  165: {'action': 3,
#   'goalPos': array([10,  2]),
#   'preqs': {164: 200,
#    408: 200,
#    507: 200,
#    508: 200,
#    509: 200,
#    753: 200,
#    824: 200,
#    825: 200,
#    826: 200,
#    827: 200,
#    1245: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 165,
#   'time': 40},
#  166: {'action': 0,
#   'goalPos': array([10,  2]),
#   'preqs': {165: 200},
#   'robotID': 2,
#   'startPos': array([10,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 166,
#   'time': 41},
#  167: {'action': 1,
#   'goalPos': array([11,  2]),
#   'preqs': {166: 200, 353: 200},
#   'robotID': 2,
#   'startPos': array([10,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 167,
#   'time': 42},
#  168: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {167: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 168,
#   'time': 43},
#  169: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {168: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 169,
#   'time': 44},
#  170: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {169: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 170,
#   'time': 45},
#  171: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {170: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 171,
#   'time': 46},
#  172: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {171: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 172,
#   'time': 47},
#  173: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {172: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 173,
#   'time': 48},
#  174: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {173: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 174,
#   'time': 49},
#  175: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {174: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 175,
#   'time': 50},
#  176: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {175: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 176,
#   'time': 51},
#  177: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {176: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 177,
#   'time': 52},
#  178: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {177: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 178,
#   'time': 53},
#  179: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {178: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 179,
#   'time': 54},
#  180: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {179: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 180,
#   'time': 55},
#  181: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {180: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 181,
#   'time': 56},
#  182: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {181: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 182,
#   'time': 57},
#  183: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {182: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 183,
#   'time': 58},
#  184: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {183: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 184,
#   'time': 59},
#  185: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {184: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 185,
#   'time': 60},
#  186: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {185: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 186,
#   'time': 61},
#  187: {'action': 2,
#   'goalPos': array([2, 1]),
#   'preqs': {},
#   'robotID': 3,
#   'startPos': array([2, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 187,
#   'time': 0},
#  188: {'action': 1,
#   'goalPos': array([3, 1]),
#   'preqs': {187: 200},
#   'robotID': 3,
#   'startPos': array([2, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 188,
#   'time': 1},
#  189: {'action': 0,
#   'goalPos': array([3, 1]),
#   'preqs': {188: 200},
#   'robotID': 3,
#   'startPos': array([3, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 189,
#   'time': 2},
#  190: {'action': 4,
#   'goalPos': array([3, 0]),
#   'preqs': {189: 200},
#   'robotID': 3,
#   'startPos': array([3, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 190,
#   'time': 3},
#  191: {'action': 3,
#   'goalPos': array([2, 0]),
#   'preqs': {190: 200},
#   'robotID': 3,
#   'startPos': array([3, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 191,
#   'time': 4},
#  192: {'action': 3,
#   'goalPos': array([1, 0]),
#   'preqs': {191: 200},
#   'robotID': 3,
#   'startPos': array([2, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 192,
#   'time': 5},
#  193: {'action': 3,
#   'goalPos': array([0, 0]),
#   'preqs': {192: 200},
#   'robotID': 3,
#   'startPos': array([1, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 193,
#   'time': 6},
#  194: {'action': 2,
#   'goalPos': array([0, 1]),
#   'preqs': {193: 200},
#   'robotID': 3,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 194,
#   'time': 7},
#  195: {'action': 2,
#   'goalPos': array([0, 2]),
#   'preqs': {194: 200},
#   'robotID': 3,
#   'startPos': array([0, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 195,
#   'time': 8},
#  196: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {195: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 196,
#   'time': 9},
#  197: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {196: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 197,
#   'time': 10},
#  198: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {197: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 198,
#   'time': 11},
#  199: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {198: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 199,
#   'time': 12},
#  200: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {199: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 200,
#   'time': 13},
#  201: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {200: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 201,
#   'time': 14},
#  202: {'action': 2,
#   'goalPos': array([0, 3]),
#   'preqs': {201: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 202,
#   'time': 15},
#  203: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {202: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 203,
#   'time': 16},
#  204: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {203: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 204,
#   'time': 17},
#  205: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {204: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 205,
#   'time': 18},
#  206: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {205: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 206,
#   'time': 19},
#  207: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {206: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 207,
#   'time': 20},
#  208: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {207: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 208,
#   'time': 21},
#  209: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {208: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 209,
#   'time': 22},
#  210: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {209: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 210,
#   'time': 23},
#  211: {'action': 1,
#   'goalPos': array([1, 3]),
#   'preqs': {210: 200, 21: 200, 436: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 211,
#   'time': 24},
#  212: {'action': 2,
#   'goalPos': array([1, 4]),
#   'preqs': {211: 200, 435: 200, 1616: 200},
#   'robotID': 3,
#   'startPos': array([1, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 212,
#   'time': 25},
#  213: {'action': 0,
#   'goalPos': array([1, 4]),
#   'preqs': {212: 200},
#   'robotID': 3,
#   'startPos': array([1, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 213,
#   'time': 26},
#  214: {'action': 0,
#   'goalPos': array([1, 4]),
#   'preqs': {213: 200},
#   'robotID': 3,
#   'startPos': array([1, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 214,
#   'time': 27},
#  215: {'action': 0,
#   'goalPos': array([1, 4]),
#   'preqs': {214: 200},
#   'robotID': 3,
#   'startPos': array([1, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 215,
#   'time': 28},
#  216: {'action': 4,
#   'goalPos': array([1, 3]),
#   'preqs': {215: 200},
#   'robotID': 3,
#   'startPos': array([1, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 216,
#   'time': 29},
#  217: {'action': 1,
#   'goalPos': array([2, 3]),
#   'preqs': {216: 200, 20: 200, 437: 200, 1618: 200, 1701: 200},
#   'robotID': 3,
#   'startPos': array([1, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 217,
#   'time': 30},
#  218: {'action': 0,
#   'goalPos': array([2, 3]),
#   'preqs': {217: 200},
#   'robotID': 3,
#   'startPos': array([2, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 218,
#   'time': 31},
#  219: {'action': 4,
#   'goalPos': array([2, 2]),
#   'preqs': {218: 200, 24: 200, 438: 200, 814: 200, 1619: 200, 1702: 200},
#   'robotID': 3,
#   'startPos': array([2, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 219,
#   'time': 32},
#  220: {'action': 3,
#   'goalPos': array([1, 2]),
#   'preqs': {219: 200,
#    22: 200,
#    23: 200,
#    807: 200,
#    808: 200,
#    809: 200,
#    810: 200,
#    811: 200,
#    812: 200,
#    813: 200},
#   'robotID': 3,
#   'startPos': array([2, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 220,
#   'time': 33},
#  221: {'action': 2,
#   'goalPos': array([1, 3]),
#   'preqs': {220: 200},
#   'robotID': 3,
#   'startPos': array([1, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 221,
#   'time': 34},
#  222: {'action': 2,
#   'goalPos': array([1, 4]),
#   'preqs': {221: 200},
#   'robotID': 3,
#   'startPos': array([1, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 222,
#   'time': 35},
#  223: {'action': 2,
#   'goalPos': array([1, 5]),
#   'preqs': {222: 200, 1615: 200},
#   'robotID': 3,
#   'startPos': array([1, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 223,
#   'time': 36},
#  224: {'action': 0,
#   'goalPos': array([1, 5]),
#   'preqs': {223: 200},
#   'robotID': 3,
#   'startPos': array([1, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 224,
#   'time': 37},
#  225: {'action': 0,
#   'goalPos': array([1, 5]),
#   'preqs': {224: 200},
#   'robotID': 3,
#   'startPos': array([1, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 225,
#   'time': 38},
#  226: {'action': 3,
#   'goalPos': array([0, 5]),
#   'preqs': {225: 200},
#   'robotID': 3,
#   'startPos': array([1, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 226,
#   'time': 39},
#  227: {'action': 2,
#   'goalPos': array([0, 6]),
#   'preqs': {226: 200, 722: 200, 906: 200},
#   'robotID': 3,
#   'startPos': array([0, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 227,
#   'time': 40},
#  228: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {227: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 228,
#   'time': 41},
#  229: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {228: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 229,
#   'time': 42},
#  230: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {229: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 230,
#   'time': 43},
#  231: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {230: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 231,
#   'time': 44},
#  232: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {231: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 232,
#   'time': 45},
#  233: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {232: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 233,
#   'time': 46},
#  234: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {233: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 234,
#   'time': 47},
#  235: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {234: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 235,
#   'time': 48},
#  236: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {235: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 236,
#   'time': 49},
#  237: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {236: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 237,
#   'time': 50},
#  238: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {237: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 238,
#   'time': 51},
#  239: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {238: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 239,
#   'time': 52},
#  240: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {239: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 240,
#   'time': 53},
#  241: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {240: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 241,
#   'time': 54},
#  242: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {241: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 242,
#   'time': 55},
#  243: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {242: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 243,
#   'time': 56},
#  244: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {243: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 244,
#   'time': 57},
#  245: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {244: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 245,
#   'time': 58},
#  246: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {245: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 246,
#   'time': 59},
#  247: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {246: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 247,
#   'time': 60},
#  248: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {247: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 248,
#   'time': 61},
#  249: {'action': 0,
#   'goalPos': array([10,  1]),
#   'preqs': {},
#   'robotID': 4,
#   'startPos': array([10,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 249,
#   'time': 0},
#  250: {'action': 0,
#   'goalPos': array([10,  1]),
#   'preqs': {249: 200},
#   'robotID': 4,
#   'startPos': array([10,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 250,
#   'time': 1},
#  251: {'action': 0,
#   'goalPos': array([10,  1]),
#   'preqs': {250: 200},
#   'robotID': 4,
#   'startPos': array([10,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 251,
#   'time': 2},
#  252: {'action': 0,
#   'goalPos': array([10,  1]),
#   'preqs': {251: 200},
#   'robotID': 4,
#   'startPos': array([10,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 252,
# ...
#   'preqs': {917: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 918,
#   'time': 49},
#  919: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {918: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 919,
#   'time': 50},
#  920: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {919: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 920,
#   'time': 51},
#  921: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {920: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 921,
#   'time': 52},
#  922: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {921: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 922,
#   'time': 53},
#  923: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {922: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 923,
#   'time': 54},
#  924: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {923: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 924,
#   'time': 55},
#  925: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {924: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 925,
#   'time': 56},
#  926: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {925: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 926,
#   'time': 57},
#  927: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {926: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 927,
#   'time': 58},
#  928: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {927: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 928,
#   'time': 59},
#  929: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {928: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 929,
#   'time': 60},
#  930: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {929: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 930,
#   'time': 61},
#  931: {'action': 0,
#   'goalPos': array([ 2, 17]),
#   'preqs': {},
#   'robotID': 15,
#   'startPos': array([ 2, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 931,
#   'time': 0},
#  932: {'action': 0,
#   'goalPos': array([ 2, 17]),
#   'preqs': {931: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 932,
#   'time': 1},
#  933: {'action': 0,
#   'goalPos': array([ 2, 17]),
#   'preqs': {932: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 933,
#   'time': 2},
#  934: {'action': 0,
#   'goalPos': array([ 2, 17]),
#   'preqs': {933: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 934,
#   'time': 3},
#  935: {'action': 4,
#   'goalPos': array([ 2, 16]),
#   'preqs': {934: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 935,
#   'time': 4},
#  936: {'action': 3,
#   'goalPos': array([ 1, 16]),
#   'preqs': {935: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 936,
#   'time': 5},
#  937: {'action': 0,
#   'goalPos': array([ 1, 16]),
#   'preqs': {936: 200},
#   'robotID': 15,
#   'startPos': array([ 1, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 937,
#   'time': 6},
#  938: {'action': 4,
#   'goalPos': array([ 1, 15]),
#   'preqs': {937: 200},
#   'robotID': 15,
#   'startPos': array([ 1, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 938,
#   'time': 7},
#  939: {'action': 0,
#   'goalPos': array([ 1, 15]),
#   'preqs': {938: 200},
#   'robotID': 15,
#   'startPos': array([ 1, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 939,
#   'time': 8},
#  940: {'action': 0,
#   'goalPos': array([ 1, 15]),
#   'preqs': {939: 200},
#   'robotID': 15,
#   'startPos': array([ 1, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 940,
#   'time': 9},
#  941: {'action': 1,
#   'goalPos': array([ 2, 15]),
#   'preqs': {940: 200},
#   'robotID': 15,
#   'startPos': array([ 1, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 941,
#   'time': 10},
#  942: {'action': 0,
#   'goalPos': array([ 2, 15]),
#   'preqs': {941: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 942,
#   'time': 11},
#  943: {'action': 0,
#   'goalPos': array([ 2, 15]),
#   'preqs': {942: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 943,
#   'time': 12},
#  944: {'action': 0,
#   'goalPos': array([ 2, 15]),
#   'preqs': {943: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 944,
#   'time': 13},
#  945: {'action': 4,
#   'goalPos': array([ 2, 14]),
#   'preqs': {944: 200, 1675: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 945,
#   'time': 14},
#  946: {'action': 1,
#   'goalPos': array([ 3, 14]),
#   'preqs': {945: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 946,
#   'time': 15},
#  947: {'action': 0,
#   'goalPos': array([ 3, 14]),
#   'preqs': {946: 200},
#   'robotID': 15,
#   'startPos': array([ 3, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 947,
#   'time': 16},
#  948: {'action': 1,
#   'goalPos': array([ 4, 14]),
#   'preqs': {947: 200},
#   'robotID': 15,
#   'startPos': array([ 3, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 948,
#   'time': 17},
#  949: {'action': 1,
#   'goalPos': array([ 5, 14]),
#   'preqs': {948: 200, 997: 200},
#   'robotID': 15,
#   'startPos': array([ 4, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 949,
#   'time': 18},
#  950: {'action': 2,
#   'goalPos': array([ 5, 15]),
#   'preqs': {949: 200, 998: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 950,
#   'time': 19},
#  951: {'action': 0,
#   'goalPos': array([ 5, 15]),
#   'preqs': {950: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 951,
#   'time': 20},
#  952: {'action': 0,
#   'goalPos': array([ 5, 15]),
#   'preqs': {951: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 952,
#   'time': 21},
#  953: {'action': 0,
#   'goalPos': array([ 5, 15]),
#   'preqs': {952: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 953,
#   'time': 22},
#  954: {'action': 0,
#   'goalPos': array([ 5, 15]),
#   'preqs': {953: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 954,
#   'time': 23},
#  955: {'action': 4,
#   'goalPos': array([ 5, 14]),
#   'preqs': {954: 200, 1075: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 955,
#   'time': 24},
#  956: {'action': 1,
#   'goalPos': array([ 6, 14]),
#   'preqs': {955: 200, 1070: 200, 1071: 200, 1072: 200, 1073: 200, 1074: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 956,
#   'time': 25},
#  957: {'action': 0,
#   'goalPos': array([ 6, 14]),
#   'preqs': {956: 200},
#   'robotID': 15,
#   'startPos': array([ 6, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 957,
#   'time': 26},
#  958: {'action': 1,
#   'goalPos': array([ 7, 14]),
#   'preqs': {957: 200, 1069: 200},
#   'robotID': 15,
#   'startPos': array([ 6, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 958,
#   'time': 27},
#  959: {'action': 1,
#   'goalPos': array([ 8, 14]),
#   'preqs': {958: 200, 460: 200, 1068: 200, 1392: 200},
#   'robotID': 15,
#   'startPos': array([ 7, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 959,
#   'time': 28},
#  960: {'action': 1,
#   'goalPos': array([ 9, 14]),
#   'preqs': {959: 200, 461: 200, 1065: 200, 1066: 200, 1067: 200, 1393: 200},
#   'robotID': 15,
#   'startPos': array([ 8, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 960,
#   'time': 29},
#  961: {'action': 1,
#   'goalPos': array([10, 14]),
#   'preqs': {960: 200, 462: 200, 1064: 200, 1394: 200},
#   'robotID': 15,
#   'startPos': array([ 9, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 961,
#   'time': 30},
#  962: {'action': 1,
#   'goalPos': array([11, 14]),
#   'preqs': {961: 200, 463: 200, 1063: 200, 1258: 200, 1395: 200},
#   'robotID': 15,
#   'startPos': array([10, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 962,
#   'time': 31},
#  963: {'action': 1,
#   'goalPos': array([12, 14]),
#   'preqs': {962: 200, 464: 200, 1062: 200, 1259: 200, 1396: 200},
#   'robotID': 15,
#   'startPos': array([11, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 963,
#   'time': 32},
#  964: {'action': 0,
#   'goalPos': array([12, 14]),
#   'preqs': {963: 200},
#   'robotID': 15,
#   'startPos': array([12, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 964,
#   'time': 33},
#  965: {'action': 0,
#   'goalPos': array([12, 14]),
#   'preqs': {964: 200},
#   'robotID': 15,
#   'startPos': array([12, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 965,
#   'time': 34},
#  966: {'action': 1,
#   'goalPos': array([13, 14]),
#   'preqs': {965: 200,
#    465: 200,
#    1061: 200,
#    1260: 200,
#    1397: 200,
#    1398: 200,
#    1399: 200,
#    1400: 200},
#   'robotID': 15,
#   'startPos': array([12, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 966,
#   'time': 35},
#  967: {'action': 1,
#   'goalPos': array([14, 14]),
#   'preqs': {966: 200, 132: 200, 466: 200, 1060: 200, 1261: 200, 1401: 200},
#   'robotID': 15,
#   'startPos': array([13, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 967,
#   'time': 36},
#  968: {'action': 1,
#   'goalPos': array([15, 14]),
#   'preqs': {967: 200, 131: 200, 1059: 200, 1402: 200},
#   'robotID': 15,
#   'startPos': array([14, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 968,
#   'time': 37},
#  969: {'action': 1,
#   'goalPos': array([16, 14]),
#   'preqs': {968: 200, 130: 200, 1058: 200, 1403: 200},
#   'robotID': 15,
#   'startPos': array([15, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 969,
#   'time': 38},
#  970: {'action': 1,
#   'goalPos': array([17, 14]),
#   'preqs': {969: 200, 129: 200, 589: 200, 1057: 200, 1404: 200, 1820: 200},
#   'robotID': 15,
#   'startPos': array([16, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 970,
#   'time': 39},
#  971: {'action': 1,
#   'goalPos': array([18, 14]),
#   'preqs': {970: 200, 588: 200},
#   'robotID': 15,
#   'startPos': array([17, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 971,
#   'time': 40},
#  972: {'action': 1,
#   'goalPos': array([19, 14]),
#   'preqs': {971: 200, 587: 200},
#   'robotID': 15,
#   'startPos': array([18, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 972,
#   'time': 41},
#  973: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {972: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 973,
#   'time': 42},
#  974: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {973: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 974,
#   'time': 43},
#  975: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {974: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 975,
#   'time': 44},
#  976: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {975: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 976,
#   'time': 45},
#  977: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {976: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 977,
#   'time': 46},
#  978: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {977: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 978,
#   'time': 47},
#  979: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {978: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 979,
#   'time': 48},
#  980: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {979: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 980,
#   'time': 49},
#  981: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {980: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 981,
#   'time': 50},
#  982: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {981: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 982,
#   'time': 51},
#  983: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {982: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 983,
#   'time': 52},
#  984: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {983: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 984,
#   'time': 53},
#  985: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {984: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 985,
#   'time': 54},
#  986: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {985: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 986,
#   'time': 55},
#  987: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {986: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 987,
#   'time': 56},
#  988: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {987: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 988,
#   'time': 57},
#  989: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {988: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 989,
#   'time': 58},
#  990: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {989: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 990,
#   'time': 59},
#  991: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {990: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 991,
#   'time': 60},
#  992: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {991: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 992,
#   'time': 61},
#  993: {'action': 2,
#   'goalPos': array([ 5, 11]),
#   'preqs': {},
#   'robotID': 16,
#   'startPos': array([ 5, 10]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 993,
#   'time': 0},
#  994: {'action': 2,
#   'goalPos': array([ 5, 12]),
#   'preqs': {993: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 11]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 994,
#   'time': 1},
#  995: {'action': 2,
#   'goalPos': array([ 5, 13]),
#   'preqs': {994: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 12]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 995,
#   'time': 2},
#  996: {'action': 2,
#   'goalPos': array([ 5, 14]),
#   'preqs': {995: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 13]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 996,
#   'time': 3},
#  997: {'action': 2,
#   'goalPos': array([ 5, 15]),
#   'preqs': {996: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 997,
#   'time': 4},
#  998: {'action': 2,
#   'goalPos': array([ 5, 16]),
#   'preqs': {997: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 998,
#   'time': 5},
#  999: {'action': 2,
#   'goalPos': array([ 5, 17]),
#   'preqs': {998: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 999,
#   'time': 6},
#  1000: {'action': 2,
#   'goalPos': array([ 5, 18]),
#   'preqs': {999: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 1000,
#   'time': 7},
#  ...}

# %%
temp2 = {}
for i in G2.graph:
    temp2[i] = {}
    for j in dir(G2.taskDict[i]):
        # print(j)
        if not j.startswith("__"):
            temp2[i][j] = getattr(G2.taskDict[i], j)

# %%
temp2
# Out:
# {1: {'action': 0,
#   'goalPos': array([2, 7]),
#   'preqs': {},
#   'robotID': 0,
#   'startPos': array([2, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 1,
#   'time': 0},
#  2: {'action': 0,
#   'goalPos': array([2, 7]),
#   'preqs': {1: 200},
#   'robotID': 0,
#   'startPos': array([2, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 2,
#   'time': 1},
#  3: {'action': 3,
#   'goalPos': array([1, 7]),
#   'preqs': {2: 200, 1613: 200},
#   'robotID': 0,
#   'startPos': array([2, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 3,
#   'time': 2},
#  4: {'action': 0,
#   'goalPos': array([1, 7]),
#   'preqs': {3: 200},
#   'robotID': 0,
#   'startPos': array([1, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 4,
#   'time': 3},
#  5: {'action': 0,
#   'goalPos': array([1, 7]),
#   'preqs': {4: 200},
#   'robotID': 0,
#   'startPos': array([1, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 5,
#   'time': 4},
#  6: {'action': 0,
#   'goalPos': array([1, 7]),
#   'preqs': {5: 200},
#   'robotID': 0,
#   'startPos': array([1, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 6,
#   'time': 5},
#  7: {'action': 0,
#   'goalPos': array([1, 7]),
#   'preqs': {6: 200},
#   'robotID': 0,
#   'startPos': array([1, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 7,
#   'time': 6},
#  8: {'action': 2,
#   'goalPos': array([1, 8]),
#   'preqs': {7: 200},
#   'robotID': 0,
#   'startPos': array([1, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 8,
#   'time': 7},
#  9: {'action': 1,
#   'goalPos': array([2, 8]),
#   'preqs': {8: 200},
#   'robotID': 0,
#   'startPos': array([1, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 9,
#   'time': 8},
#  10: {'action': 0,
#   'goalPos': array([2, 8]),
#   'preqs': {9: 200},
#   'robotID': 0,
#   'startPos': array([2, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 10,
#   'time': 9},
#  11: {'action': 0,
#   'goalPos': array([2, 8]),
#   'preqs': {10: 200},
#   'robotID': 0,
#   'startPos': array([2, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 11,
#   'time': 10},
#  12: {'action': 3,
#   'goalPos': array([1, 8]),
#   'preqs': {11: 200},
#   'robotID': 0,
#   'startPos': array([2, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 12,
#   'time': 11},
#  13: {'action': 1,
#   'goalPos': array([2, 8]),
#   'preqs': {12: 200},
#   'robotID': 0,
#   'startPos': array([1, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 13,
#   'time': 12},
#  14: {'action': 4,
#   'goalPos': array([2, 7]),
#   'preqs': {13: 200},
#   'robotID': 0,
#   'startPos': array([2, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 14,
#   'time': 13},
#  15: {'action': 4,
#   'goalPos': array([2, 6]),
#   'preqs': {14: 200},
#   'robotID': 0,
#   'startPos': array([2, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 15,
#   'time': 14},
#  16: {'action': 4,
#   'goalPos': array([2, 5]),
#   'preqs': {15: 200},
#   'robotID': 0,
#   'startPos': array([2, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 16,
#   'time': 15},
#  17: {'action': 4,
#   'goalPos': array([2, 4]),
#   'preqs': {16: 200, 1617: 200},
#   'robotID': 0,
#   'startPos': array([2, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 17,
#   'time': 16},
#  18: {'action': 0,
#   'goalPos': array([2, 4]),
#   'preqs': {17: 200},
#   'robotID': 0,
#   'startPos': array([2, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 18,
#   'time': 17},
#  19: {'action': 4,
#   'goalPos': array([2, 3]),
#   'preqs': {18: 200, 437: 200, 1618: 200},
#   'robotID': 0,
#   'startPos': array([2, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 19,
#   'time': 18},
#  20: {'action': 3,
#   'goalPos': array([1, 3]),
#   'preqs': {19: 200, 436: 200},
#   'robotID': 0,
#   'startPos': array([2, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 20,
#   'time': 19},
#  21: {'action': 4,
#   'goalPos': array([1, 2]),
#   'preqs': {20: 200,
#    808: 200,
#    809: 200,
#    810: 200,
#    811: 200,
#    812: 200,
#    813: 200,
#    807: 200},
#   'robotID': 0,
#   'startPos': array([1, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 21,
#   'time': 20},
#  22: {'action': 0,
#   'goalPos': array([1, 2]),
#   'preqs': {21: 200},
#   'robotID': 0,
#   'startPos': array([1, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 22,
#   'time': 21},
#  23: {'action': 1,
#   'goalPos': array([2, 2]),
#   'preqs': {22: 200, 438: 200, 1619: 200, 814: 200},
#   'robotID': 0,
#   'startPos': array([1, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 23,
#   'time': 22},
#  24: {'action': 1,
#   'goalPos': array([3, 2]),
#   'preqs': {23: 200, 439: 200, 1620: 200, 815: 200},
#   'robotID': 0,
#   'startPos': array([2, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 24,
#   'time': 23},
#  25: {'action': 1,
#   'goalPos': array([4, 2]),
#   'preqs': {24: 200, 440: 200, 1621: 200, 816: 200, 817: 200},
#   'robotID': 0,
#   'startPos': array([3, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 25,
#   'time': 24},
#  26: {'action': 4,
#   'goalPos': array([4, 1]),
#   'preqs': {25: 200},
#   'robotID': 0,
#   'startPos': array([4, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 26,
#   'time': 25},
#  27: {'action': 4,
#   'goalPos': array([4, 0]),
#   'preqs': {26: 200},
#   'robotID': 0,
#   'startPos': array([4, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 27,
#   'time': 26},
#  28: {'action': 1,
#   'goalPos': array([5, 0]),
#   'preqs': {27: 200, 1368: 200},
#   'robotID': 0,
#   'startPos': array([4, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 28,
#   'time': 27},
#  29: {'action': 1,
#   'goalPos': array([6, 0]),
#   'preqs': {28: 200, 80: 200},
#   'robotID': 0,
#   'startPos': array([5, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 29,
#   'time': 28},
#  30: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {29: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 30,
#   'time': 29},
#  31: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {30: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 31,
#   'time': 30},
#  32: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {31: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 32,
#   'time': 31},
#  33: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {32: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 33,
#   'time': 32},
#  34: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {33: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 34,
#   'time': 33},
#  35: {'action': 0,
#   'goalPos': array([6, 0]),
#   'preqs': {34: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 35,
#   'time': 34},
#  36: {'action': 1,
#   'goalPos': array([7, 0]),
#   'preqs': {35: 200, 746: 200, 263: 200, 264: 200, 79: 200, 270: 200},
#   'robotID': 0,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 36,
#   'time': 35},
#  37: {'action': 1,
#   'goalPos': array([8, 0]),
#   'preqs': {36: 200,
#    747: 200,
#    260: 200,
#    261: 200,
#    262: 200,
#    78: 200,
#    271: 200},
#   'robotID': 0,
#   'startPos': array([7, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 37,
#   'time': 36},
#  38: {'action': 1,
#   'goalPos': array([9, 0]),
#   'preqs': {37: 200, 77: 200, 1629: 200, 1630: 200, 1631: 200, 1632: 200},
#   'robotID': 0,
#   'startPos': array([8, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 38,
#   'time': 37},
#  39: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {38: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 39,
#   'time': 38},
#  40: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {39: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 40,
#   'time': 39},
#  41: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {40: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 41,
#   'time': 40},
#  42: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {41: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 42,
#   'time': 41},
#  43: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {42: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 43,
#   'time': 42},
#  44: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {43: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 44,
#   'time': 43},
#  45: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {44: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 45,
#   'time': 44},
#  46: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {45: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 46,
#   'time': 45},
#  47: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {46: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 47,
#   'time': 46},
#  48: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {47: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 48,
#   'time': 47},
#  49: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {48: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 49,
#   'time': 48},
#  50: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {49: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 50,
#   'time': 49},
#  51: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {50: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 51,
#   'time': 50},
#  52: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {51: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 52,
#   'time': 51},
#  53: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {52: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 53,
#   'time': 52},
#  54: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {53: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 54,
#   'time': 53},
#  55: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {54: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 55,
#   'time': 54},
#  56: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {55: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 56,
#   'time': 55},
#  57: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {56: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 57,
#   'time': 56},
#  58: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {57: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 58,
#   'time': 57},
#  59: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {58: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 59,
#   'time': 58},
#  60: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {59: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 60,
#   'time': 59},
#  61: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {60: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 61,
#   'time': 60},
#  62: {'action': 0,
#   'goalPos': array([9, 0]),
#   'preqs': {61: 200},
#   'robotID': 0,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 62,
#   'time': 61},
#  63: {'action': 4,
#   'goalPos': array([20,  0]),
#   'preqs': {},
#   'robotID': 1,
#   'startPos': array([20,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 63,
#   'time': 0},
#  64: {'action': 3,
#   'goalPos': array([19,  0]),
#   'preqs': {63: 200},
#   'robotID': 1,
#   'startPos': array([20,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 64,
#   'time': 1},
#  65: {'action': 3,
#   'goalPos': array([18,  0]),
#   'preqs': {64: 200},
#   'robotID': 1,
#   'startPos': array([19,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 65,
#   'time': 2},
#  66: {'action': 2,
#   'goalPos': array([18,  1]),
#   'preqs': {65: 200},
#   'robotID': 1,
#   'startPos': array([18,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 66,
#   'time': 3},
#  67: {'action': 3,
#   'goalPos': array([17,  1]),
#   'preqs': {66: 200},
#   'robotID': 1,
#   'startPos': array([18,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 67,
#   'time': 4},
#  68: {'action': 3,
#   'goalPos': array([16,  1]),
#   'preqs': {67: 200, 1802: 200},
#   'robotID': 1,
#   'startPos': array([17,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 68,
#   'time': 5},
#  69: {'action': 3,
#   'goalPos': array([15,  1]),
#   'preqs': {68: 200},
#   'robotID': 1,
#   'startPos': array([16,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 69,
#   'time': 6},
#  70: {'action': 4,
#   'goalPos': array([15,  0]),
#   'preqs': {69: 200},
#   'robotID': 1,
#   'startPos': array([15,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 70,
#   'time': 7},
#  71: {'action': 3,
#   'goalPos': array([14,  0]),
#   'preqs': {70: 200},
#   'robotID': 1,
#   'startPos': array([15,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 71,
#   'time': 8},
#  72: {'action': 3,
#   'goalPos': array([13,  0]),
#   'preqs': {71: 200},
#   'robotID': 1,
#   'startPos': array([14,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 72,
#   'time': 9},
#  73: {'action': 3,
#   'goalPos': array([12,  0]),
#   'preqs': {72: 200},
#   'robotID': 1,
#   'startPos': array([13,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 73,
#   'time': 10},
#  74: {'action': 3,
#   'goalPos': array([11,  0]),
#   'preqs': {73: 200},
#   'robotID': 1,
#   'startPos': array([12,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 74,
#   'time': 11},
#  75: {'action': 3,
#   'goalPos': array([10,  0]),
#   'preqs': {74: 200},
#   'robotID': 1,
#   'startPos': array([11,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 75,
#   'time': 12},
#  76: {'action': 3,
#   'goalPos': array([9, 0]),
#   'preqs': {75: 200},
#   'robotID': 1,
#   'startPos': array([10,  0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 76,
#   'time': 13},
#  77: {'action': 3,
#   'goalPos': array([8, 0]),
#   'preqs': {76: 200, 747: 200, 260: 200, 261: 200, 262: 200},
#   'robotID': 1,
#   'startPos': array([9, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 77,
#   'time': 14},
#  78: {'action': 3,
#   'goalPos': array([7, 0]),
#   'preqs': {77: 200, 746: 200, 263: 200, 264: 200},
#   'robotID': 1,
#   'startPos': array([8, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 78,
#   'time': 15},
#  79: {'action': 3,
#   'goalPos': array([6, 0]),
#   'preqs': {78: 200},
#   'robotID': 1,
#   'startPos': array([7, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 79,
#   'time': 16},
#  80: {'action': 2,
#   'goalPos': array([6, 1]),
#   'preqs': {79: 200, 1373: 200, 1625: 200},
#   'robotID': 1,
#   'startPos': array([6, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 80,
#   'time': 17},
#  81: {'action': 3,
#   'goalPos': array([5, 1]),
#   'preqs': {80: 200, 1367: 200, 1369: 200, 1374: 200},
#   'robotID': 1,
#   'startPos': array([6, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 81,
#   'time': 18},
#  82: {'action': 2,
#   'goalPos': array([5, 2]),
#   'preqs': {81: 200,
#    1366: 200,
#    500: 200,
#    1370: 200,
#    441: 200,
#    1622: 200,
#    1375: 200,
#    818: 200},
#   'robotID': 1,
#   'startPos': array([5, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 82,
#   'time': 19},
#  83: {'action': 2,
#   'goalPos': array([5, 3]),
#   'preqs': {82: 200, 499: 200, 442: 200, 1376: 200, 1365: 200},
#   'robotID': 1,
#   'startPos': array([5, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 83,
#   'time': 20},
#  84: {'action': 2,
#   'goalPos': array([5, 4]),
#   'preqs': {83: 200, 498: 200, 443: 200, 1377: 200},
#   'robotID': 1,
#   'startPos': array([5, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 84,
#   'time': 21},
#  85: {'action': 2,
#   'goalPos': array([5, 5]),
#   'preqs': {84: 200, 444: 200, 1378: 200, 497: 200},
#   'robotID': 1,
#   'startPos': array([5, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 85,
#   'time': 22},
#  86: {'action': 2,
#   'goalPos': array([5, 6]),
#   'preqs': {85: 200, 445: 200, 1379: 200},
#   'robotID': 1,
#   'startPos': array([5, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 86,
#   'time': 23},
#  87: {'action': 2,
#   'goalPos': array([5, 7]),
#   'preqs': {86: 200, 446: 200, 447: 200, 1380: 200},
#   'robotID': 1,
#   'startPos': array([5, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 87,
#   'time': 24},
#  88: {'action': 2,
#   'goalPos': array([5, 8]),
#   'preqs': {87: 200, 448: 200, 1381: 200},
#   'robotID': 1,
#   'startPos': array([5, 7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 88,
#   'time': 25},
#  89: {'action': 2,
#   'goalPos': array([5, 9]),
#   'preqs': {88: 200},
#   'robotID': 1,
#   'startPos': array([5, 8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 89,
#   'time': 26},
#  90: {'action': 2,
#   'goalPos': array([ 5, 10]),
#   'preqs': {89: 200, 993: 200},
#   'robotID': 1,
#   'startPos': array([5, 9]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 90,
#   'time': 27},
#  91: {'action': 2,
#   'goalPos': array([ 5, 11]),
#   'preqs': {90: 200, 994: 200},
#   'robotID': 1,
#   'startPos': array([ 5, 10]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 91,
#   'time': 28},
#  92: {'action': 2,
#   'goalPos': array([ 5, 12]),
#   'preqs': {91: 200, 995: 200},
#   'robotID': 1,
#   'startPos': array([ 5, 11]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 92,
#   'time': 29},
#  93: {'action': 2,
#   'goalPos': array([ 5, 13]),
#   'preqs': {92: 200, 996: 200},
#   'robotID': 1,
#   'startPos': array([ 5, 12]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 93,
#   'time': 30},
#  94: {'action': 2,
#   'goalPos': array([ 5, 14]),
#   'preqs': {93: 200, 997: 200, 950: 200, 1075: 200, 956: 200},
#   'robotID': 1,
#   'startPos': array([ 5, 13]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 94,
#   'time': 31},
#  95: {'action': 3,
#   'goalPos': array([ 4, 14]),
#   'preqs': {94: 200, 949: 200, 1076: 200},
#   'robotID': 1,
#   'startPos': array([ 5, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 95,
#   'time': 32},
#  96: {'action': 3,
#   'goalPos': array([ 3, 14]),
#   'preqs': {95: 200, 947: 200, 948: 200, 1077: 200},
#   'robotID': 1,
#   'startPos': array([ 4, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 96,
#   'time': 33},
#  97: {'action': 3,
#   'goalPos': array([ 2, 14]),
#   'preqs': {96: 200, 946: 200, 1078: 200, 1675: 200},
#   'robotID': 1,
#   'startPos': array([ 3, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 97,
#   'time': 34},
#  98: {'action': 2,
#   'goalPos': array([ 2, 15]),
#   'preqs': {97: 200, 942: 200, 943: 200, 944: 200, 945: 200},
#   'robotID': 1,
#   'startPos': array([ 2, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 98,
#   'time': 35},
#  99: {'action': 3,
#   'goalPos': array([ 1, 15]),
#   'preqs': {98: 200, 939: 200, 940: 200, 941: 200},
#   'robotID': 1,
#   'startPos': array([ 2, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 99,
#   'time': 36},
#  100: {'action': 2,
#   'goalPos': array([ 1, 16]),
#   'preqs': {99: 200, 937: 200, 938: 200},
#   'robotID': 1,
#   'startPos': array([ 1, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 100,
#   'time': 37},
#  101: {'action': 3,
#   'goalPos': array([ 0, 16]),
#   'preqs': {100: 200, 1141: 200, 895: 200, 712: 200},
#   'robotID': 1,
#   'startPos': array([ 1, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 101,
#   'time': 38},
#  102: {'action': 2,
#   'goalPos': array([ 0, 17]),
#   'preqs': {101: 200, 1140: 200, 894: 200, 711: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 102,
#   'time': 39},
#  103: {'action': 2,
#   'goalPos': array([ 0, 18]),
#   'preqs': {102: 200, 1139: 200, 893: 200, 710: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 103,
#   'time': 40},
#  104: {'action': 2,
#   'goalPos': array([ 0, 19]),
#   'preqs': {103: 200, 1138: 200, 892: 200, 709: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 18]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 104,
#   'time': 41},
#  105: {'action': 2,
#   'goalPos': array([ 0, 20]),
#   'preqs': {104: 200, 891: 200, 708: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 105,
#   'time': 42},
#  106: {'action': 2,
#   'goalPos': array([ 0, 21]),
#   'preqs': {105: 200, 890: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 20]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 106,
#   'time': 43},
#  107: {'action': 0,
#   'goalPos': array([ 0, 21]),
#   'preqs': {106: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 21]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 107,
#   'time': 44},
#  108: {'action': 4,
#   'goalPos': array([ 0, 20]),
#   'preqs': {107: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 21]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 108,
#   'time': 45},
#  109: {'action': 4,
#   'goalPos': array([ 0, 19]),
#   'preqs': {108: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 20]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 109,
#   'time': 46},
#  110: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {109: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 110,
#   'time': 47},
#  111: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {110: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 111,
#   'time': 48},
#  112: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {111: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 112,
#   'time': 49},
#  113: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {112: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 113,
#   'time': 50},
#  114: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {113: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 114,
#   'time': 51},
#  115: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {114: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 115,
#   'time': 52},
#  116: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {115: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 116,
#   'time': 53},
#  117: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {116: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 117,
#   'time': 54},
#  118: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {117: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 118,
#   'time': 55},
#  119: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {118: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 119,
#   'time': 56},
#  120: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {119: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 120,
#   'time': 57},
#  121: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {120: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 121,
#   'time': 58},
#  122: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {121: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 122,
#   'time': 59},
#  123: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {122: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 123,
#   'time': 60},
#  124: {'action': 0,
#   'goalPos': array([ 0, 19]),
#   'preqs': {123: 200},
#   'robotID': 1,
#   'startPos': array([ 0, 19]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 124,
#   'time': 61},
#  125: {'action': 4,
#   'goalPos': array([17, 15]),
#   'preqs': {},
#   'robotID': 2,
#   'startPos': array([17, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 125,
#   'time': 0},
#  126: {'action': 0,
#   'goalPos': array([17, 15]),
#   'preqs': {125: 200},
#   'robotID': 2,
#   'startPos': array([17, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 126,
#   'time': 1},
#  127: {'action': 0,
#   'goalPos': array([17, 15]),
#   'preqs': {126: 200},
#   'robotID': 2,
#   'startPos': array([17, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 127,
#   'time': 2},
#  128: {'action': 4,
#   'goalPos': array([17, 14]),
#   'preqs': {127: 200, 1057: 200},
#   'robotID': 2,
#   'startPos': array([17, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 128,
#   'time': 3},
#  129: {'action': 3,
#   'goalPos': array([16, 14]),
#   'preqs': {128: 200, 1058: 200},
#   'robotID': 2,
#   'startPos': array([17, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 129,
#   'time': 4},
#  130: {'action': 3,
#   'goalPos': array([15, 14]),
#   'preqs': {129: 200, 1059: 200},
#   'robotID': 2,
#   'startPos': array([16, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 130,
#   'time': 5},
#  131: {'action': 3,
#   'goalPos': array([14, 14]),
#   'preqs': {130: 200, 1060: 200},
#   'robotID': 2,
#   'startPos': array([15, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 131,
#   'time': 6},
#  132: {'action': 4,
#   'goalPos': array([14, 13]),
#   'preqs': {131: 200},
#   'robotID': 2,
#   'startPos': array([14, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 132,
#   'time': 7},
#  133: {'action': 4,
#   'goalPos': array([14, 12]),
#   'preqs': {132: 200, 1489: 200},
#   'robotID': 2,
#   'startPos': array([14, 13]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 133,
#   'time': 8},
#  134: {'action': 4,
#   'goalPos': array([14, 11]),
#   'preqs': {133: 200, 1490: 200, 1491: 200},
#   'robotID': 2,
#   'startPos': array([14, 12]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 134,
#   'time': 9},
#  135: {'action': 4,
#   'goalPos': array([14, 10]),
#   'preqs': {134: 200, 1492: 200},
#   'robotID': 2,
#   'startPos': array([14, 11]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 135,
#   'time': 10},
#  136: {'action': 4,
#   'goalPos': array([14,  9]),
#   'preqs': {135: 200, 1493: 200},
#   'robotID': 2,
#   'startPos': array([14, 10]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 136,
#   'time': 11},
#  137: {'action': 4,
#   'goalPos': array([14,  8]),
#   'preqs': {136: 200, 1494: 200},
#   'robotID': 2,
#   'startPos': array([14,  9]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 137,
#   'time': 12},
#  138: {'action': 1,
#   'goalPos': array([15,  8]),
#   'preqs': {137: 200},
#   'robotID': 2,
#   'startPos': array([14,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 138,
#   'time': 13},
#  139: {'action': 0,
#   'goalPos': array([15,  8]),
#   'preqs': {138: 200},
#   'robotID': 2,
#   'startPos': array([15,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 139,
#   'time': 14},
#  140: {'action': 0,
#   'goalPos': array([15,  8]),
#   'preqs': {139: 200},
#   'robotID': 2,
#   'startPos': array([15,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 140,
#   'time': 15},
#  141: {'action': 0,
#   'goalPos': array([15,  8]),
#   'preqs': {140: 200},
#   'robotID': 2,
#   'startPos': array([15,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 141,
#   'time': 16},
#  142: {'action': 3,
#   'goalPos': array([14,  8]),
#   'preqs': {141: 200, 1504: 200},
#   'robotID': 2,
#   'startPos': array([15,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 142,
#   'time': 17},
#  143: {'action': 4,
#   'goalPos': array([14,  7]),
#   'preqs': {142: 200,
#    1495: 200,
#    1496: 200,
#    1497: 200,
#    1498: 200,
#    1499: 200,
#    1500: 200,
#    1501: 200,
#    1502: 200,
#    1503: 200},
#   'robotID': 2,
#   'startPos': array([14,  8]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 143,
#   'time': 18},
#  144: {'action': 4,
#   'goalPos': array([14,  6]),
#   'preqs': {143: 200},
#   'robotID': 2,
#   'startPos': array([14,  7]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 144,
#   'time': 19},
#  145: {'action': 4,
#   'goalPos': array([14,  5]),
#   'preqs': {144: 200},
#   'robotID': 2,
#   'startPos': array([14,  6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 145,
#   'time': 20},
#  146: {'action': 4,
#   'goalPos': array([14,  4]),
#   'preqs': {145: 200},
#   'robotID': 2,
#   'startPos': array([14,  5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 146,
#   'time': 21},
#  147: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {146: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 147,
#   'time': 22},
#  148: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {147: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 148,
#   'time': 23},
#  149: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {148: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 149,
#   'time': 24},
#  150: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {149: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 150,
#   'time': 25},
#  151: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {150: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 151,
#   'time': 26},
#  152: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {151: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 152,
#   'time': 27},
#  153: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {152: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 153,
#   'time': 28},
#  154: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {153: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 154,
#   'time': 29},
#  155: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {154: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 155,
#   'time': 30},
#  156: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {155: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 156,
#   'time': 31},
#  157: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {156: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 157,
#   'time': 32},
#  158: {'action': 0,
#   'goalPos': array([14,  4]),
#   'preqs': {157: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 158,
#   'time': 33},
#  159: {'action': 4,
#   'goalPos': array([14,  3]),
#   'preqs': {158: 200},
#   'robotID': 2,
#   'startPos': array([14,  4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 159,
#   'time': 34},
#  160: {'action': 4,
#   'goalPos': array([14,  2]),
#   'preqs': {159: 200, 757: 200, 760: 200, 514: 200, 404: 200},
#   'robotID': 2,
#   'startPos': array([14,  3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 160,
#   'time': 35},
#  161: {'action': 0,
#   'goalPos': array([14,  2]),
#   'preqs': {160: 200},
#   'robotID': 2,
#   'startPos': array([14,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 161,
#   'time': 36},
#  162: {'action': 3,
#   'goalPos': array([13,  2]),
#   'preqs': {161: 200, 756: 200, 513: 200, 405: 200},
#   'robotID': 2,
#   'startPos': array([14,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 162,
#   'time': 37},
#  163: {'action': 3,
#   'goalPos': array([12,  2]),
#   'preqs': {162: 200, 755: 200, 511: 200, 512: 200, 406: 200},
#   'robotID': 2,
#   'startPos': array([13,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 163,
#   'time': 38},
#  164: {'action': 3,
#   'goalPos': array([11,  2]),
#   'preqs': {163: 200, 1246: 200, 754: 200, 510: 200, 828: 200, 407: 200},
#   'robotID': 2,
#   'startPos': array([12,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 164,
#   'time': 39},
#  165: {'action': 3,
#   'goalPos': array([10,  2]),
#   'preqs': {164: 200,
#    1245: 200,
#    753: 200,
#    507: 200,
#    508: 200,
#    509: 200,
#    824: 200,
#    825: 200,
#    826: 200,
#    827: 200,
#    408: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 165,
#   'time': 40},
#  166: {'action': 0,
#   'goalPos': array([10,  2]),
#   'preqs': {165: 200},
#   'robotID': 2,
#   'startPos': array([10,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 166,
#   'time': 41},
#  167: {'action': 1,
#   'goalPos': array([11,  2]),
#   'preqs': {166: 200, 353: 200},
#   'robotID': 2,
#   'startPos': array([10,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 167,
#   'time': 42},
#  168: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {167: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 168,
#   'time': 43},
#  169: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {168: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 169,
#   'time': 44},
#  170: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {169: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 170,
#   'time': 45},
#  171: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {170: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 171,
#   'time': 46},
#  172: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {171: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 172,
#   'time': 47},
#  173: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {172: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 173,
#   'time': 48},
#  174: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {173: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 174,
#   'time': 49},
#  175: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {174: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 175,
#   'time': 50},
#  176: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {175: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 176,
#   'time': 51},
#  177: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {176: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 177,
#   'time': 52},
#  178: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {177: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 178,
#   'time': 53},
#  179: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {178: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 179,
#   'time': 54},
#  180: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {179: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 180,
#   'time': 55},
#  181: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {180: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 181,
#   'time': 56},
#  182: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {181: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 182,
#   'time': 57},
#  183: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {182: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 183,
#   'time': 58},
#  184: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {183: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 184,
#   'time': 59},
#  185: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {184: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 185,
#   'time': 60},
#  186: {'action': 0,
#   'goalPos': array([11,  2]),
#   'preqs': {185: 200},
#   'robotID': 2,
#   'startPos': array([11,  2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 186,
#   'time': 61},
#  187: {'action': 2,
#   'goalPos': array([2, 1]),
#   'preqs': {},
#   'robotID': 3,
#   'startPos': array([2, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 187,
#   'time': 0},
#  188: {'action': 1,
#   'goalPos': array([3, 1]),
#   'preqs': {187: 200},
#   'robotID': 3,
#   'startPos': array([2, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 188,
#   'time': 1},
#  189: {'action': 0,
#   'goalPos': array([3, 1]),
#   'preqs': {188: 200},
#   'robotID': 3,
#   'startPos': array([3, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 189,
#   'time': 2},
#  190: {'action': 4,
#   'goalPos': array([3, 0]),
#   'preqs': {189: 200},
#   'robotID': 3,
#   'startPos': array([3, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 190,
#   'time': 3},
#  191: {'action': 3,
#   'goalPos': array([2, 0]),
#   'preqs': {190: 200},
#   'robotID': 3,
#   'startPos': array([3, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 191,
#   'time': 4},
#  192: {'action': 3,
#   'goalPos': array([1, 0]),
#   'preqs': {191: 200},
#   'robotID': 3,
#   'startPos': array([2, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 192,
#   'time': 5},
#  193: {'action': 3,
#   'goalPos': array([0, 0]),
#   'preqs': {192: 200},
#   'robotID': 3,
#   'startPos': array([1, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 193,
#   'time': 6},
#  194: {'action': 2,
#   'goalPos': array([0, 1]),
#   'preqs': {193: 200},
#   'robotID': 3,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 194,
#   'time': 7},
#  195: {'action': 2,
#   'goalPos': array([0, 2]),
#   'preqs': {194: 200},
#   'robotID': 3,
#   'startPos': array([0, 1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 195,
#   'time': 8},
#  196: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {195: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 196,
#   'time': 9},
#  197: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {196: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 197,
#   'time': 10},
#  198: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {197: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 198,
#   'time': 11},
#  199: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {198: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 199,
#   'time': 12},
#  200: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {199: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 200,
#   'time': 13},
#  201: {'action': 0,
#   'goalPos': array([0, 2]),
#   'preqs': {200: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 201,
#   'time': 14},
#  202: {'action': 2,
#   'goalPos': array([0, 3]),
#   'preqs': {201: 200},
#   'robotID': 3,
#   'startPos': array([0, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 202,
#   'time': 15},
#  203: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {202: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 203,
#   'time': 16},
#  204: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {203: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 204,
#   'time': 17},
#  205: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {204: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 205,
#   'time': 18},
#  206: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {205: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 206,
#   'time': 19},
#  207: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {206: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 207,
#   'time': 20},
#  208: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {207: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 208,
#   'time': 21},
#  209: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {208: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 209,
#   'time': 22},
#  210: {'action': 0,
#   'goalPos': array([0, 3]),
#   'preqs': {209: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 210,
#   'time': 23},
#  211: {'action': 1,
#   'goalPos': array([1, 3]),
#   'preqs': {210: 200, 436: 200, 21: 200},
#   'robotID': 3,
#   'startPos': array([0, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 211,
#   'time': 24},
#  212: {'action': 2,
#   'goalPos': array([1, 4]),
#   'preqs': {211: 200, 1616: 200, 435: 200},
#   'robotID': 3,
#   'startPos': array([1, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 212,
#   'time': 25},
#  213: {'action': 0,
#   'goalPos': array([1, 4]),
#   'preqs': {212: 200},
#   'robotID': 3,
#   'startPos': array([1, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 213,
#   'time': 26},
#  214: {'action': 0,
#   'goalPos': array([1, 4]),
#   'preqs': {213: 200},
#   'robotID': 3,
#   'startPos': array([1, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 214,
#   'time': 27},
#  215: {'action': 0,
#   'goalPos': array([1, 4]),
#   'preqs': {214: 200},
#   'robotID': 3,
#   'startPos': array([1, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 215,
#   'time': 28},
#  216: {'action': 4,
#   'goalPos': array([1, 3]),
#   'preqs': {215: 200},
#   'robotID': 3,
#   'startPos': array([1, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 216,
#   'time': 29},
#  217: {'action': 1,
#   'goalPos': array([2, 3]),
#   'preqs': {216: 200, 437: 200, 1618: 200, 20: 200, 1701: 200},
#   'robotID': 3,
#   'startPos': array([1, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 217,
#   'time': 30},
#  218: {'action': 0,
#   'goalPos': array([2, 3]),
#   'preqs': {217: 200},
#   'robotID': 3,
#   'startPos': array([2, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 218,
#   'time': 31},
#  219: {'action': 4,
#   'goalPos': array([2, 2]),
#   'preqs': {218: 200, 438: 200, 1619: 200, 814: 200, 24: 200, 1702: 200},
#   'robotID': 3,
#   'startPos': array([2, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 219,
#   'time': 32},
#  220: {'action': 3,
#   'goalPos': array([1, 2]),
#   'preqs': {219: 200,
#    808: 200,
#    809: 200,
#    810: 200,
#    811: 200,
#    812: 200,
#    813: 200,
#    22: 200,
#    23: 200,
#    807: 200},
#   'robotID': 3,
#   'startPos': array([2, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 220,
#   'time': 33},
#  221: {'action': 2,
#   'goalPos': array([1, 3]),
#   'preqs': {220: 200},
#   'robotID': 3,
#   'startPos': array([1, 2]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 221,
#   'time': 34},
#  222: {'action': 2,
#   'goalPos': array([1, 4]),
#   'preqs': {221: 200},
#   'robotID': 3,
#   'startPos': array([1, 3]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 222,
#   'time': 35},
#  223: {'action': 2,
#   'goalPos': array([1, 5]),
#   'preqs': {222: 200, 1615: 200},
#   'robotID': 3,
#   'startPos': array([1, 4]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 223,
#   'time': 36},
#  224: {'action': 0,
#   'goalPos': array([1, 5]),
#   'preqs': {223: 200},
#   'robotID': 3,
#   'startPos': array([1, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 224,
#   'time': 37},
#  225: {'action': 0,
#   'goalPos': array([1, 5]),
#   'preqs': {224: 200},
#   'robotID': 3,
#   'startPos': array([1, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 225,
#   'time': 38},
#  226: {'action': 3,
#   'goalPos': array([0, 5]),
#   'preqs': {225: 200},
#   'robotID': 3,
#   'startPos': array([1, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 226,
#   'time': 39},
#  227: {'action': 2,
#   'goalPos': array([0, 6]),
#   'preqs': {226: 200, 906: 200, 722: 200},
#   'robotID': 3,
#   'startPos': array([0, 5]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 227,
#   'time': 40},
#  228: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {227: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 228,
#   'time': 41},
#  229: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {228: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 229,
#   'time': 42},
#  230: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {229: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 230,
#   'time': 43},
#  231: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {230: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 231,
#   'time': 44},
#  232: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {231: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 232,
#   'time': 45},
#  233: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {232: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 233,
#   'time': 46},
#  234: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {233: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 234,
#   'time': 47},
#  235: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {234: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 235,
#   'time': 48},
#  236: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {235: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 236,
#   'time': 49},
#  237: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {236: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 237,
#   'time': 50},
#  238: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {237: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 238,
#   'time': 51},
#  239: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {238: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 239,
#   'time': 52},
#  240: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {239: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 240,
#   'time': 53},
#  241: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {240: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 241,
#   'time': 54},
#  242: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {241: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 242,
#   'time': 55},
#  243: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {242: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 243,
#   'time': 56},
#  244: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {243: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 244,
#   'time': 57},
#  245: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {244: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 245,
#   'time': 58},
#  246: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {245: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 246,
#   'time': 59},
#  247: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {246: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 247,
#   'time': 60},
#  248: {'action': 0,
#   'goalPos': array([0, 6]),
#   'preqs': {247: 200},
#   'robotID': 3,
#   'startPos': array([0, 6]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 248,
#   'time': 61},
#  249: {'action': 0,
#   'goalPos': array([10,  1]),
#   'preqs': {},
#   'robotID': 4,
#   'startPos': array([10,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 249,
#   'time': 0},
#  250: {'action': 0,
#   'goalPos': array([10,  1]),
#   'preqs': {249: 200},
#   'robotID': 4,
#   'startPos': array([10,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 250,
#   'time': 1},
#  251: {'action': 0,
#   'goalPos': array([10,  1]),
#   'preqs': {250: 200},
#   'robotID': 4,
#   'startPos': array([10,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 251,
#   'time': 2},
#  252: {'action': 0,
#   'goalPos': array([10,  1]),
#   'preqs': {251: 200},
#   'robotID': 4,
#   'startPos': array([10,  1]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 252,
# ...
#   'preqs': {917: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 918,
#   'time': 49},
#  919: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {918: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 919,
#   'time': 50},
#  920: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {919: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 920,
#   'time': 51},
#  921: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {920: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 921,
#   'time': 52},
#  922: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {921: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 922,
#   'time': 53},
#  923: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {922: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 923,
#   'time': 54},
#  924: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {923: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 924,
#   'time': 55},
#  925: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {924: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 925,
#   'time': 56},
#  926: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {925: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 926,
#   'time': 57},
#  927: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {926: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 927,
#   'time': 58},
#  928: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {927: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 928,
#   'time': 59},
#  929: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {928: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 929,
#   'time': 60},
#  930: {'action': 0,
#   'goalPos': array([0, 0]),
#   'preqs': {929: 200},
#   'robotID': 14,
#   'startPos': array([0, 0]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 930,
#   'time': 61},
#  931: {'action': 0,
#   'goalPos': array([ 2, 17]),
#   'preqs': {},
#   'robotID': 15,
#   'startPos': array([ 2, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 931,
#   'time': 0},
#  932: {'action': 0,
#   'goalPos': array([ 2, 17]),
#   'preqs': {931: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 932,
#   'time': 1},
#  933: {'action': 0,
#   'goalPos': array([ 2, 17]),
#   'preqs': {932: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 933,
#   'time': 2},
#  934: {'action': 0,
#   'goalPos': array([ 2, 17]),
#   'preqs': {933: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 934,
#   'time': 3},
#  935: {'action': 4,
#   'goalPos': array([ 2, 16]),
#   'preqs': {934: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 935,
#   'time': 4},
#  936: {'action': 3,
#   'goalPos': array([ 1, 16]),
#   'preqs': {935: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 936,
#   'time': 5},
#  937: {'action': 0,
#   'goalPos': array([ 1, 16]),
#   'preqs': {936: 200},
#   'robotID': 15,
#   'startPos': array([ 1, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 937,
#   'time': 6},
#  938: {'action': 4,
#   'goalPos': array([ 1, 15]),
#   'preqs': {937: 200},
#   'robotID': 15,
#   'startPos': array([ 1, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 938,
#   'time': 7},
#  939: {'action': 0,
#   'goalPos': array([ 1, 15]),
#   'preqs': {938: 200},
#   'robotID': 15,
#   'startPos': array([ 1, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 939,
#   'time': 8},
#  940: {'action': 0,
#   'goalPos': array([ 1, 15]),
#   'preqs': {939: 200},
#   'robotID': 15,
#   'startPos': array([ 1, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 940,
#   'time': 9},
#  941: {'action': 1,
#   'goalPos': array([ 2, 15]),
#   'preqs': {940: 200},
#   'robotID': 15,
#   'startPos': array([ 1, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 941,
#   'time': 10},
#  942: {'action': 0,
#   'goalPos': array([ 2, 15]),
#   'preqs': {941: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 942,
#   'time': 11},
#  943: {'action': 0,
#   'goalPos': array([ 2, 15]),
#   'preqs': {942: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 943,
#   'time': 12},
#  944: {'action': 0,
#   'goalPos': array([ 2, 15]),
#   'preqs': {943: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 944,
#   'time': 13},
#  945: {'action': 4,
#   'goalPos': array([ 2, 14]),
#   'preqs': {944: 200, 1675: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 945,
#   'time': 14},
#  946: {'action': 1,
#   'goalPos': array([ 3, 14]),
#   'preqs': {945: 200},
#   'robotID': 15,
#   'startPos': array([ 2, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 946,
#   'time': 15},
#  947: {'action': 0,
#   'goalPos': array([ 3, 14]),
#   'preqs': {946: 200},
#   'robotID': 15,
#   'startPos': array([ 3, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 947,
#   'time': 16},
#  948: {'action': 1,
#   'goalPos': array([ 4, 14]),
#   'preqs': {947: 200},
#   'robotID': 15,
#   'startPos': array([ 3, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 948,
#   'time': 17},
#  949: {'action': 1,
#   'goalPos': array([ 5, 14]),
#   'preqs': {948: 200, 997: 200},
#   'robotID': 15,
#   'startPos': array([ 4, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 949,
#   'time': 18},
#  950: {'action': 2,
#   'goalPos': array([ 5, 15]),
#   'preqs': {949: 200, 998: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 950,
#   'time': 19},
#  951: {'action': 0,
#   'goalPos': array([ 5, 15]),
#   'preqs': {950: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 951,
#   'time': 20},
#  952: {'action': 0,
#   'goalPos': array([ 5, 15]),
#   'preqs': {951: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 952,
#   'time': 21},
#  953: {'action': 0,
#   'goalPos': array([ 5, 15]),
#   'preqs': {952: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 953,
#   'time': 22},
#  954: {'action': 0,
#   'goalPos': array([ 5, 15]),
#   'preqs': {953: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 954,
#   'time': 23},
#  955: {'action': 4,
#   'goalPos': array([ 5, 14]),
#   'preqs': {954: 200, 1075: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 955,
#   'time': 24},
#  956: {'action': 1,
#   'goalPos': array([ 6, 14]),
#   'preqs': {955: 200, 1070: 200, 1071: 200, 1072: 200, 1073: 200, 1074: 200},
#   'robotID': 15,
#   'startPos': array([ 5, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 956,
#   'time': 25},
#  957: {'action': 0,
#   'goalPos': array([ 6, 14]),
#   'preqs': {956: 200},
#   'robotID': 15,
#   'startPos': array([ 6, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 957,
#   'time': 26},
#  958: {'action': 1,
#   'goalPos': array([ 7, 14]),
#   'preqs': {957: 200, 1069: 200},
#   'robotID': 15,
#   'startPos': array([ 6, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 958,
#   'time': 27},
#  959: {'action': 1,
#   'goalPos': array([ 8, 14]),
#   'preqs': {958: 200, 1068: 200, 460: 200, 1392: 200},
#   'robotID': 15,
#   'startPos': array([ 7, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 959,
#   'time': 28},
#  960: {'action': 1,
#   'goalPos': array([ 9, 14]),
#   'preqs': {959: 200, 1065: 200, 1066: 200, 1067: 200, 461: 200, 1393: 200},
#   'robotID': 15,
#   'startPos': array([ 8, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 960,
#   'time': 29},
#  961: {'action': 1,
#   'goalPos': array([10, 14]),
#   'preqs': {960: 200, 1064: 200, 462: 200, 1394: 200},
#   'robotID': 15,
#   'startPos': array([ 9, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 961,
#   'time': 30},
#  962: {'action': 1,
#   'goalPos': array([11, 14]),
#   'preqs': {961: 200, 1063: 200, 1258: 200, 463: 200, 1395: 200},
#   'robotID': 15,
#   'startPos': array([10, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 962,
#   'time': 31},
#  963: {'action': 1,
#   'goalPos': array([12, 14]),
#   'preqs': {962: 200, 1062: 200, 1259: 200, 464: 200, 1396: 200},
#   'robotID': 15,
#   'startPos': array([11, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 963,
#   'time': 32},
#  964: {'action': 0,
#   'goalPos': array([12, 14]),
#   'preqs': {963: 200},
#   'robotID': 15,
#   'startPos': array([12, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 964,
#   'time': 33},
#  965: {'action': 0,
#   'goalPos': array([12, 14]),
#   'preqs': {964: 200},
#   'robotID': 15,
#   'startPos': array([12, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 965,
#   'time': 34},
#  966: {'action': 1,
#   'goalPos': array([13, 14]),
#   'preqs': {965: 200,
#    1061: 200,
#    1260: 200,
#    465: 200,
#    1397: 200,
#    1398: 200,
#    1399: 200,
#    1400: 200},
#   'robotID': 15,
#   'startPos': array([12, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 966,
#   'time': 35},
#  967: {'action': 1,
#   'goalPos': array([14, 14]),
#   'preqs': {966: 200, 1060: 200, 132: 200, 1261: 200, 466: 200, 1401: 200},
#   'robotID': 15,
#   'startPos': array([13, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 967,
#   'time': 36},
#  968: {'action': 1,
#   'goalPos': array([15, 14]),
#   'preqs': {967: 200, 1059: 200, 131: 200, 1402: 200},
#   'robotID': 15,
#   'startPos': array([14, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 968,
#   'time': 37},
#  969: {'action': 1,
#   'goalPos': array([16, 14]),
#   'preqs': {968: 200, 1058: 200, 130: 200, 1403: 200},
#   'robotID': 15,
#   'startPos': array([15, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 969,
#   'time': 38},
#  970: {'action': 1,
#   'goalPos': array([17, 14]),
#   'preqs': {969: 200, 1057: 200, 129: 200, 1820: 200, 589: 200, 1404: 200},
#   'robotID': 15,
#   'startPos': array([16, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 970,
#   'time': 39},
#  971: {'action': 1,
#   'goalPos': array([18, 14]),
#   'preqs': {970: 200, 588: 200},
#   'robotID': 15,
#   'startPos': array([17, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 971,
#   'time': 40},
#  972: {'action': 1,
#   'goalPos': array([19, 14]),
#   'preqs': {971: 200, 587: 200},
#   'robotID': 15,
#   'startPos': array([18, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 972,
#   'time': 41},
#  973: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {972: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 973,
#   'time': 42},
#  974: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {973: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 974,
#   'time': 43},
#  975: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {974: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 975,
#   'time': 44},
#  976: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {975: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 976,
#   'time': 45},
#  977: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {976: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 977,
#   'time': 46},
#  978: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {977: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 978,
#   'time': 47},
#  979: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {978: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 979,
#   'time': 48},
#  980: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {979: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 980,
#   'time': 49},
#  981: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {980: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 981,
#   'time': 50},
#  982: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {981: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 982,
#   'time': 51},
#  983: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {982: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 983,
#   'time': 52},
#  984: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {983: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 984,
#   'time': 53},
#  985: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {984: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 985,
#   'time': 54},
#  986: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {985: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 986,
#   'time': 55},
#  987: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {986: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 987,
#   'time': 56},
#  988: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {987: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 988,
#   'time': 57},
#  989: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {988: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 989,
#   'time': 58},
#  990: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {989: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 990,
#   'time': 59},
#  991: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {990: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 991,
#   'time': 60},
#  992: {'action': 0,
#   'goalPos': array([19, 14]),
#   'preqs': {991: 200},
#   'robotID': 15,
#   'startPos': array([19, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 992,
#   'time': 61},
#  993: {'action': 2,
#   'goalPos': array([ 5, 11]),
#   'preqs': {},
#   'robotID': 16,
#   'startPos': array([ 5, 10]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 993,
#   'time': 0},
#  994: {'action': 2,
#   'goalPos': array([ 5, 12]),
#   'preqs': {993: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 11]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 994,
#   'time': 1},
#  995: {'action': 2,
#   'goalPos': array([ 5, 13]),
#   'preqs': {994: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 12]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 995,
#   'time': 2},
#  996: {'action': 2,
#   'goalPos': array([ 5, 14]),
#   'preqs': {995: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 13]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 996,
#   'time': 3},
#  997: {'action': 2,
#   'goalPos': array([ 5, 15]),
#   'preqs': {996: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 14]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 997,
#   'time': 4},
#  998: {'action': 2,
#   'goalPos': array([ 5, 16]),
#   'preqs': {997: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 15]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 998,
#   'time': 5},
#  999: {'action': 2,
#   'goalPos': array([ 5, 17]),
#   'preqs': {998: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 16]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 999,
#   'time': 6},
#  1000: {'action': 2,
#   'goalPos': array([ 5, 18]),
#   'preqs': {999: 200},
#   'robotID': 16,
#   'startPos': array([ 5, 17]),
#   'status': <Status.STAGED: 200>,
#   'taskID': 1000,
#   'time': 7},
#  ...}

# %%
temp = {}
for i in GRAPH.graph:
    temp[i] = {}
    temp[i]["action"] = int(GRAPH.taskDict[i].action)
    temp[i]["preqs"] = list(GRAPH.taskDict[i].preqs.keys())
    temp[i]["robotID"] = GRAPH.taskDict[i].robotID

# %%
temp
# Out:
# {1: {'action': 0, 'preqs': [], 'robotID': 0},
#  2: {'action': 0, 'preqs': [1], 'robotID': 0},
#  3: {'action': 3, 'preqs': [2, 1613], 'robotID': 0},
#  4: {'action': 0, 'preqs': [3], 'robotID': 0},
#  5: {'action': 0, 'preqs': [4], 'robotID': 0},
#  6: {'action': 0, 'preqs': [5], 'robotID': 0},
#  7: {'action': 0, 'preqs': [6], 'robotID': 0},
#  8: {'action': 2, 'preqs': [7], 'robotID': 0},
#  9: {'action': 1, 'preqs': [8], 'robotID': 0},
#  10: {'action': 0, 'preqs': [9], 'robotID': 0},
#  11: {'action': 0, 'preqs': [10], 'robotID': 0},
#  12: {'action': 3, 'preqs': [11], 'robotID': 0},
#  13: {'action': 1, 'preqs': [12], 'robotID': 0},
#  14: {'action': 4, 'preqs': [13], 'robotID': 0},
#  15: {'action': 4, 'preqs': [14], 'robotID': 0},
#  16: {'action': 4, 'preqs': [15], 'robotID': 0},
#  17: {'action': 4, 'preqs': [16, 1617], 'robotID': 0},
#  18: {'action': 0, 'preqs': [17], 'robotID': 0},
#  19: {'action': 4, 'preqs': [18, 437, 1618], 'robotID': 0},
#  20: {'action': 3, 'preqs': [19, 436], 'robotID': 0},
#  21: {'action': 4,
#   'preqs': [20, 807, 808, 809, 810, 811, 812, 813],
#   'robotID': 0},
#  22: {'action': 0, 'preqs': [21], 'robotID': 0},
#  23: {'action': 1, 'preqs': [22, 438, 814, 1619], 'robotID': 0},
#  24: {'action': 1, 'preqs': [23, 439, 815, 1620], 'robotID': 0},
#  25: {'action': 1, 'preqs': [24, 440, 816, 817, 1621], 'robotID': 0},
#  26: {'action': 4, 'preqs': [25], 'robotID': 0},
#  27: {'action': 4, 'preqs': [26], 'robotID': 0},
#  28: {'action': 1, 'preqs': [27, 1368], 'robotID': 0},
#  29: {'action': 1, 'preqs': [28, 80], 'robotID': 0},
#  317: {'action': 4, 'preqs': [316], 'robotID': 5},
#  318: {'action': 4, 'preqs': [317], 'robotID': 5},
#  319: {'action': 4, 'preqs': [318], 'robotID': 5},
#  320: {'action': 4, 'preqs': [319], 'robotID': 5},
#  321: {'action': 4, 'preqs': [320], 'robotID': 5},
#  322: {'action': 1, 'preqs': [321], 'robotID': 5},
#  323: {'action': 4, 'preqs': [322], 'robotID': 5},
#  324: {'action': 0, 'preqs': [323], 'robotID': 5},
#  325: {'action': 4, 'preqs': [324], 'robotID': 5},
#  326: {'action': 4, 'preqs': [325], 'robotID': 5},
#  327: {'action': 3, 'preqs': [326, 1436], 'robotID': 5},
#  328: {'action': 4, 'preqs': [327, 1435], 'robotID': 5},
#  329: {'action': 4, 'preqs': [328, 1434], 'robotID': 5},
#  330: {'action': 4, 'preqs': [329, 1433], 'robotID': 5},
#  331: {'action': 4, 'preqs': [330, 377, 1432], 'robotID': 5},
#  332: {'action': 4, 'preqs': [331, 1431], 'robotID': 5},
#  333: {'action': 4, 'preqs': [332, 392, 1430], 'robotID': 5},
#  334: {'action': 4, 'preqs': [333, 393, 1429], 'robotID': 5},
#  335: {'action': 4, 'preqs': [334, 1428], 'robotID': 5},
#  336: {'action': 4, 'preqs': [335, 1427], 'robotID': 5},
#  337: {'action': 4, 'preqs': [336, 398], 'robotID': 5},
#  338: {'action': 3, 'preqs': [337, 399], 'robotID': 5},
#  339: {'action': 0, 'preqs': [338], 'robotID': 5},
#  340: {'action': 0, 'preqs': [339], 'robotID': 5},
#  341: {'action': 3, 'preqs': [340, 400], 'robotID': 5},
#  342: {'action': 3, 'preqs': [341, 401, 763, 1643, 1804], 'robotID': 5},
#  343: {'action': 3, 'preqs': [342, 402, 762, 1800, 1801, 1803], 'robotID': 5},
#  344: {'action': 3, 'preqs': [343, 403, 515, 761, 1799], 'robotID': 5},
#  345: {'action': 4, 'preqs': [344, 70, 516], 'robotID': 5},
#  346: {'action': 0, 'preqs': [345], 'robotID': 5},
#  347: {'action': 2, 'preqs': [346], 'robotID': 5},
#  348: {'action': 0, 'preqs': [347], 'robotID': 5},
#  349: {'action': 3,
#   'preqs': [348, 161, 162, 404, 514, 757, 760],
#   'robotID': 5},
#  350: {'action': 3, 'preqs': [349, 163, 405, 513, 756], 'robotID': 5},
#  351: {'action': 3, 'preqs': [350, 164, 406, 511, 512, 755], 'robotID': 5},
#  352: {'action': 3,
#   'preqs': [351, 165, 407, 510, 754, 828, 1246],
#   'robotID': 5},
#  353: {'action': 2, 'preqs': [352, 829, 1247], 'robotID': 5},
#  354: {'action': 2, 'preqs': [353, 830, 1248], 'robotID': 5},
#  355: {'action': 0, 'preqs': [354], 'robotID': 5},
#  356: {'action': 0, 'preqs': [355], 'robotID': 5},
#  357: {'action': 0, 'preqs': [356], 'robotID': 5},
#  358: {'action': 0, 'preqs': [357], 'robotID': 5},
#  359: {'action': 0, 'preqs': [358], 'robotID': 5},
#  360: {'action': 0, 'preqs': [359], 'robotID': 5},
#  554: {'action': 0, 'preqs': [553], 'robotID': 8},
#  555: {'action': 0, 'preqs': [554], 'robotID': 8},
#  556: {'action': 0, 'preqs': [555], 'robotID': 8},
#  557: {'action': 0, 'preqs': [556], 'robotID': 8},
#  558: {'action': 0, 'preqs': [557], 'robotID': 8},
#  559: {'action': 2, 'preqs': [], 'robotID': 9},
#  560: {'action': 0, 'preqs': [559], 'robotID': 9},
#  561: {'action': 0, 'preqs': [560], 'robotID': 9},
#  562: {'action': 0, 'preqs': [561], 'robotID': 9},
#  563: {'action': 0, 'preqs': [562], 'robotID': 9},
#  564: {'action': 2, 'preqs': [563, 687], 'robotID': 9},
#  565: {'action': 1, 'preqs': [564, 686], 'robotID': 9},
#  566: {'action': 2, 'preqs': [565], 'robotID': 9},
#  567: {'action': 4, 'preqs': [566], 'robotID': 9},
#  568: {'action': 0, 'preqs': [567], 'robotID': 9},
#  569: {'action': 1, 'preqs': [568, 685, 1551, 1552], 'robotID': 9},
#  570: {'action': 1, 'preqs': [569, 317, 684], 'robotID': 9},
#  571: {'action': 0, 'preqs': [570], 'robotID': 9},
#  572: {'action': 2, 'preqs': [571, 316, 1554, 1555], 'robotID': 9},
#  573: {'action': 1, 'preqs': [572], 'robotID': 9},
#  574: {'action': 0, 'preqs': [573], 'robotID': 9},
#  575: {'action': 0, 'preqs': [574], 'robotID': 9},
#  576: {'action': 4, 'preqs': [575, 683, 1567], 'robotID': 9},
#  577: {'action': 4, 'preqs': [576, 1568], 'robotID': 9},
#  578: {'action': 4, 'preqs': [577, 1569], 'robotID': 9},
#  579: {'action': 1, 'preqs': [578, 1570], 'robotID': 9},
#  580: {'action': 4, 'preqs': [579, 1571], 'robotID': 9},
#  581: {'action': 4, 'preqs': [580, 1572], 'robotID': 9},
#  582: {'action': 3, 'preqs': [581], 'robotID': 9},
#  583: {'action': 3, 'preqs': [582, 321, 1440], 'robotID': 9},
#  584: {'action': 4, 'preqs': [583, 322, 1439], 'robotID': 9},
#  585: {'action': 4, 'preqs': [584, 1438], 'robotID': 9},
#  586: {'action': 3, 'preqs': [585], 'robotID': 9},
#  587: {'action': 3, 'preqs': [586], 'robotID': 9},
#  588: {'action': 3, 'preqs': [587, 129, 1057, 1820], 'robotID': 9},
#  589: {'action': 2, 'preqs': [588, 126, 127, 128, 1821], 'robotID': 9},
#  590: {'action': 0, 'preqs': [589], 'robotID': 9},
#  591: {'action': 0, 'preqs': [590], 'robotID': 9},
#  592: {'action': 0, 'preqs': [591], 'robotID': 9},
#  593: {'action': 0, 'preqs': [592], 'robotID': 9},
#  594: {'action': 0, 'preqs': [593], 'robotID': 9},
#  595: {'action': 0, 'preqs': [594], 'robotID': 9},
#  596: {'action': 0, 'preqs': [595], 'robotID': 9},
#  597: {'action': 0, 'preqs': [596], 'robotID': 9},
#  598: {'action': 0, 'preqs': [597], 'robotID': 9},
#  599: {'action': 0, 'preqs': [598], 'robotID': 9},
#  600: {'action': 0, 'preqs': [599], 'robotID': 9},
#  601: {'action': 0, 'preqs': [600], 'robotID': 9},
#  602: {'action': 0, 'preqs': [601], 'robotID': 9},
#  603: {'action': 0, 'preqs': [602], 'robotID': 9},
#  604: {'action': 0, 'preqs': [603], 'robotID': 9},
#  605: {'action': 0, 'preqs': [604], 'robotID': 9},
#  606: {'action': 4, 'preqs': [605, 852, 971, 1404], 'robotID': 9},
#  607: {'action': 3, 'preqs': [606, 130, 851, 970, 1058, 1403], 'robotID': 9},
#  608: {'action': 3, 'preqs': [607, 131, 850, 969, 1059, 1402], 'robotID': 9},
#  609: {'action': 3,
#   'preqs': [608, 132, 466, 849, 968, 1060, 1261, 1401],
#   'robotID': 9},
#  610: {'action': 3,
#   'preqs': [609, 465, 848, 967, 1061, 1260, 1397, 1398, 1399, 1400],
#   'robotID': 9},
#  611: {'action': 3,
#   'preqs': [610, 464, 847, 964, 965, 966, 1062, 1259, 1396],
#   'robotID': 9},
#  612: {'action': 3,
#   'preqs': [611, 463, 846, 963, 1063, 1258, 1395],
#   'robotID': 9},
#  613: {'action': 0, 'preqs': [612], 'robotID': 9},
#  614: {'action': 0, 'preqs': [613], 'robotID': 9},
#  615: {'action': 0, 'preqs': [614], 'robotID': 9},
#  616: {'action': 0, 'preqs': [615], 'robotID': 9},
#  617: {'action': 0, 'preqs': [616], 'robotID': 9},
#  618: {'action': 0, 'preqs': [617], 'robotID': 9},
#  619: {'action': 0, 'preqs': [618], 'robotID': 9},
#  620: {'action': 0, 'preqs': [619], 'robotID': 9},
#  621: {'action': 3, 'preqs': [], 'robotID': 10},
#  622: {'action': 4, 'preqs': [621], 'robotID': 10},
#  623: {'action': 4, 'preqs': [622], 'robotID': 10},
#  624: {'action': 1, 'preqs': [623], 'robotID': 10},
#  625: {'action': 2, 'preqs': [624], 'robotID': 10},
#  626: {'action': 1, 'preqs': [625], 'robotID': 10},
#  627: {'action': 2, 'preqs': [626, 1119], 'robotID': 10},
#  628: {'action': 4, 'preqs': [627, 1186], 'robotID': 10},
#  629: {'action': 1, 'preqs': [628, 1306], 'robotID': 10},
#  630: {'action': 4, 'preqs': [629, 1188, 1305], 'robotID': 10},
#  631: {'action': 1, 'preqs': [630, 1189], 'robotID': 10},
#  632: {'action': 1, 'preqs': [631, 1190, 1741], 'robotID': 10},
#  633: {'action': 1, 'preqs': [632, 692, 1191, 1740], 'robotID': 10},
#  634: {'action': 0, 'preqs': [633], 'robotID': 10},
#  635: {'action': 1, 'preqs': [634, 691, 1192, 1739], 'robotID': 10},
#  636: {'action': 1, 'preqs': [635, 690, 1193], 'robotID': 10},
#  637: {'action': 1, 'preqs': [636, 689, 1194], 'robotID': 10},
#  638: {'action': 1, 'preqs': [637, 688, 1195], 'robotID': 10},
#  639: {'action': 1, 'preqs': [638, 565, 687, 1196], 'robotID': 10},
#  640: {'action': 0, 'preqs': [639], 'robotID': 10},
#  641: {'action': 1,
#   'preqs': [640, 566, 568, 569, 686, 1197, 1320],
#   'robotID': 10},
#  642: {'action': 2, 'preqs': [641, 567, 1319, 1447], 'robotID': 10},
#  643: {'action': 0, 'preqs': [642], 'robotID': 10},
#  644: {'action': 0, 'preqs': [643], 'robotID': 10},
#  645: {'action': 0, 'preqs': [644], 'robotID': 10},
#  646: {'action': 1, 'preqs': [645, 315, 1446, 1553, 1564], 'robotID': 10},
#  647: {'action': 4,
#   'preqs': [646, 570, 685, 1198, 1321, 1551, 1552, 1565],
#   'robotID': 10},
#  648: {'action': 1,
#   'preqs': [647, 317, 571, 572, 684, 1199, 1322, 1444, 1566],
#   'robotID': 10},
#  649: {'action': 4, 'preqs': [648, 318, 1200, 1323, 1443], 'robotID': 10},
#  650: {'action': 4, 'preqs': [649, 319, 1201, 1442], 'robotID': 10},
#  651: {'action': 4, 'preqs': [650, 320, 1202, 1203, 1441], 'robotID': 10},
#  652: {'action': 4, 'preqs': [651, 321, 584, 1440], 'robotID': 10},
#  653: {'action': 4, 'preqs': [652, 322, 585, 1439], 'robotID': 10},
#  654: {'action': 1, 'preqs': [653, 323, 1334], 'robotID': 10},
#  655: {'action': 3, 'preqs': [654], 'robotID': 10},
#  656: {'action': 4, 'preqs': [655, 586, 1337, 1438], 'robotID': 10},
#  657: {'action': 0, 'preqs': [656], 'robotID': 10},
#  658: {'action': 0, 'preqs': [657], 'robotID': 10},
#  659: {'action': 0, 'preqs': [658], 'robotID': 10},
#  660: {'action': 0, 'preqs': [659], 'robotID': 10},
#  661: {'action': 0, 'preqs': [660], 'robotID': 10},
#  662: {'action': 0, 'preqs': [661], 'robotID': 10},
#  663: {'action': 0, 'preqs': [662], 'robotID': 10},
#  664: {'action': 0, 'preqs': [663], 'robotID': 10},
#  665: {'action': 0, 'preqs': [664], 'robotID': 10},
#  666: {'action': 0, 'preqs': [665], 'robotID': 10},
#  667: {'action': 0, 'preqs': [666], 'robotID': 10},
#  668: {'action': 0, 'preqs': [667], 'robotID': 10},
#  669: {'action': 0, 'preqs': [668], 'robotID': 10},
#  670: {'action': 0, 'preqs': [669], 'robotID': 10},
#  671: {'action': 0, 'preqs': [670], 'robotID': 10},
#  672: {'action': 0, 'preqs': [671], 'robotID': 10},
#  673: {'action': 0, 'preqs': [672], 'robotID': 10},
#  674: {'action': 0, 'preqs': [673], 'robotID': 10},
#  675: {'action': 0, 'preqs': [674], 'robotID': 10},
#  676: {'action': 0, 'preqs': [675], 'robotID': 10},
#  677: {'action': 0, 'preqs': [676], 'robotID': 10},
#  678: {'action': 0, 'preqs': [677], 'robotID': 10},
#  679: {'action': 0, 'preqs': [678], 'robotID': 10},
#  680: {'action': 0, 'preqs': [679], 'robotID': 10},
#  681: {'action': 0, 'preqs': [680], 'robotID': 10},
#  682: {'action': 0, 'preqs': [681], 'robotID': 10},
#  683: {'action': 3, 'preqs': [], 'robotID': 11},
#  684: {'action': 3, 'preqs': [683, 1551, 1552], 'robotID': 11},
#  685: {'action': 3, 'preqs': [684], 'robotID': 11},
#  686: {'action': 3, 'preqs': [685], 'robotID': 11},
#  687: {'action': 3, 'preqs': [686], 'robotID': 11},
#  688: {'action': 3, 'preqs': [687], 'robotID': 11},
#  689: {'action': 3, 'preqs': [688], 'robotID': 11},
#  870: {'action': 3, 'preqs': [869, 1738], 'robotID': 14},
#  871: {'action': 2, 'preqs': [870], 'robotID': 14},
#  872: {'action': 3, 'preqs': [871], 'robotID': 14},
#  873: {'action': 3, 'preqs': [872], 'robotID': 14},
#  874: {'action': 3, 'preqs': [873, 1117], 'robotID': 14},
#  875: {'action': 3, 'preqs': [874, 1118], 'robotID': 14},
#  876: {'action': 3, 'preqs': [875, 628, 1119], 'robotID': 14},
#  877: {'action': 0, 'preqs': [876], 'robotID': 14},
#  878: {'action': 0, 'preqs': [877], 'robotID': 14},
#  879: {'action': 4, 'preqs': [878, 627, 629, 1186], 'robotID': 14},
#  880: {'action': 3, 'preqs': [879, 626, 1185], 'robotID': 14},
#  881: {'action': 3, 'preqs': [880, 623, 1123, 1184], 'robotID': 14},
#  882: {'action': 2, 'preqs': [881, 622, 1121, 1122], 'robotID': 14},
#  883: {'action': 3, 'preqs': [882], 'robotID': 14},
#  884: {'action': 3, 'preqs': [883, 1126, 1127], 'robotID': 14},
#  885: {'action': 3, 'preqs': [884, 1128, 1129], 'robotID': 14},
#  886: {'action': 3, 'preqs': [885, 1130, 1131, 1132], 'robotID': 14},
#  887: {'action': 4, 'preqs': [886, 1133, 1134, 1179], 'robotID': 14},
#  888: {'action': 3, 'preqs': [887, 1135], 'robotID': 14},
#  889: {'action': 3, 'preqs': [888], 'robotID': 14},
#  890: {'action': 4, 'preqs': [889], 'robotID': 14},
#  891: {'action': 4, 'preqs': [890, 1138], 'robotID': 14},
#  892: {'action': 4, 'preqs': [891, 1139], 'robotID': 14},
#  893: {'action': 4, 'preqs': [892, 1140], 'robotID': 14},
#  894: {'action': 4, 'preqs': [893, 1141], 'robotID': 14},
#  895: {'action': 4, 'preqs': [894, 1142], 'robotID': 14},
#  896: {'action': 4, 'preqs': [895, 1143], 'robotID': 14},
#  897: {'action': 4, 'preqs': [896, 1144], 'robotID': 14},
#  898: {'action': 0, 'preqs': [897], 'robotID': 14},
#  899: {'action': 4, 'preqs': [898, 1085], 'robotID': 14},
#  900: {'action': 4, 'preqs': [899, 1084, 1086], 'robotID': 14},
#  901: {'action': 4, 'preqs': [900], 'robotID': 14},
#  902: {'action': 4, 'preqs': [901], 'robotID': 14},
#  903: {'action': 4, 'preqs': [902], 'robotID': 14},
#  904: {'action': 4, 'preqs': [903], 'robotID': 14},
#  905: {'action': 4, 'preqs': [904], 'robotID': 14},
#  906: {'action': 1, 'preqs': [905, 1614], 'robotID': 14},
#  907: {'action': 1, 'preqs': [906, 16, 1698], 'robotID': 14},
#  908: {'action': 4, 'preqs': [907, 17, 1699], 'robotID': 14},
#  909: {'action': 4, 'preqs': [908, 18, 19, 1617, 1700], 'robotID': 14},
#  910: {'action': 4,
#   'preqs': [909, 20, 218, 219, 437, 1618, 1701],
#   'robotID': 14},
#  911: {'action': 4,
#   'preqs': [910, 24, 220, 438, 814, 1619, 1702],
#   'robotID': 14},
#  912: {'action': 3,
#   'preqs': [911, 22, 23, 221, 807, 808, 809, 810, 811, 812, 813],
#   'robotID': 14},
#  913: {'action': 3,
#   'preqs': [912, 196, 197, 198, 199, 200, 201, 202],
#   'robotID': 14},
#  914: {'action': 4, 'preqs': [913, 195], 'robotID': 14},
#  915: {'action': 4, 'preqs': [914, 194], 'robotID': 14},
#  916: {'action': 0, 'preqs': [915], 'robotID': 14},
#  917: {'action': 0, 'preqs': [916], 'robotID': 14},
#  918: {'action': 0, 'preqs': [917], 'robotID': 14},
#  919: {'action': 0, 'preqs': [918], 'robotID': 14},
#  920: {'action': 0, 'preqs': [919], 'robotID': 14},
#  921: {'action': 0, 'preqs': [920], 'robotID': 14},
#  922: {'action': 0, 'preqs': [921], 'robotID': 14},
#  923: {'action': 0, 'preqs': [922], 'robotID': 14},
#  924: {'action': 0, 'preqs': [923], 'robotID': 14},
#  925: {'action': 0, 'preqs': [924], 'robotID': 14},
#  926: {'action': 0, 'preqs': [925], 'robotID': 14},
#  927: {'action': 0, 'preqs': [926], 'robotID': 14},
#  928: {'action': 0, 'preqs': [927], 'robotID': 14},
#  929: {'action': 0, 'preqs': [928], 'robotID': 14},
#  930: {'action': 0, 'preqs': [929], 'robotID': 14},
#  931: {'action': 0, 'preqs': [], 'robotID': 15},
#  932: {'action': 0, 'preqs': [931], 'robotID': 15},
#  933: {'action': 0, 'preqs': [932], 'robotID': 15},
#  934: {'action': 0, 'preqs': [933], 'robotID': 15},
#  935: {'action': 4, 'preqs': [934], 'robotID': 15},
#  936: {'action': 3, 'preqs': [935], 'robotID': 15},
#  937: {'action': 0, 'preqs': [936], 'robotID': 15},
#  938: {'action': 4, 'preqs': [937], 'robotID': 15},
#  939: {'action': 0, 'preqs': [938], 'robotID': 15},
#  940: {'action': 0, 'preqs': [939], 'robotID': 15},
#  941: {'action': 1, 'preqs': [940], 'robotID': 15},
#  942: {'action': 0, 'preqs': [941], 'robotID': 15},
#  943: {'action': 0, 'preqs': [942], 'robotID': 15},
#  944: {'action': 0, 'preqs': [943], 'robotID': 15},
#  945: {'action': 4, 'preqs': [944, 1675], 'robotID': 15},
#  946: {'action': 1, 'preqs': [945], 'robotID': 15},
#  947: {'action': 0, 'preqs': [946], 'robotID': 15},
#  948: {'action': 1, 'preqs': [947], 'robotID': 15},
#  949: {'action': 1, 'preqs': [948, 997], 'robotID': 15},
#  950: {'action': 2, 'preqs': [949, 998], 'robotID': 15},
#  951: {'action': 0, 'preqs': [950], 'robotID': 15},
#  952: {'action': 0, 'preqs': [951], 'robotID': 15},
#  953: {'action': 0, 'preqs': [952], 'robotID': 15},
#  954: {'action': 0, 'preqs': [953], 'robotID': 15},
#  955: {'action': 4, 'preqs': [954, 1075], 'robotID': 15},
#  956: {'action': 1,
#   'preqs': [955, 1070, 1071, 1072, 1073, 1074],
#   'robotID': 15},
#  957: {'action': 0, 'preqs': [956], 'robotID': 15},
#  958: {'action': 1, 'preqs': [957, 1069], 'robotID': 15},
#  959: {'action': 1, 'preqs': [958, 460, 1068, 1392], 'robotID': 15},
#  960: {'action': 1,
#   'preqs': [959, 461, 1065, 1066, 1067, 1393],
#   'robotID': 15},
#  961: {'action': 1, 'preqs': [960, 462, 1064, 1394], 'robotID': 15},
#  962: {'action': 1, 'preqs': [961, 463, 1063, 1258, 1395], 'robotID': 15},
#  963: {'action': 1, 'preqs': [962, 464, 1062, 1259, 1396], 'robotID': 15},
#  964: {'action': 0, 'preqs': [963], 'robotID': 15},
#  965: {'action': 0, 'preqs': [964], 'robotID': 15},
#  966: {'action': 1,
#   'preqs': [965, 465, 1061, 1260, 1397, 1398, 1399, 1400],
#   'robotID': 15},
#  967: {'action': 1, 'preqs': [966, 132, 466, 1060, 1261, 1401], 'robotID': 15},
#  968: {'action': 1, 'preqs': [967, 131, 1059, 1402], 'robotID': 15},
#  969: {'action': 1, 'preqs': [968, 130, 1058, 1403], 'robotID': 15},
#  970: {'action': 1, 'preqs': [969, 129, 589, 1057, 1404, 1820], 'robotID': 15},
#  971: {'action': 1, 'preqs': [970, 588], 'robotID': 15},
#  972: {'action': 1, 'preqs': [971, 587], 'robotID': 15},
#  973: {'action': 0, 'preqs': [972], 'robotID': 15},
#  974: {'action': 0, 'preqs': [973], 'robotID': 15},
#  975: {'action': 0, 'preqs': [974], 'robotID': 15},
#  976: {'action': 0, 'preqs': [975], 'robotID': 15},
#  977: {'action': 0, 'preqs': [976], 'robotID': 15},
#  978: {'action': 0, 'preqs': [977], 'robotID': 15},
#  979: {'action': 0, 'preqs': [978], 'robotID': 15},
#  980: {'action': 0, 'preqs': [979], 'robotID': 15},
#  981: {'action': 0, 'preqs': [980], 'robotID': 15},
#  982: {'action': 0, 'preqs': [981], 'robotID': 15},
#  983: {'action': 0, 'preqs': [982], 'robotID': 15},
#  984: {'action': 0, 'preqs': [983], 'robotID': 15},
#  985: {'action': 0, 'preqs': [984], 'robotID': 15},
#  986: {'action': 0, 'preqs': [985], 'robotID': 15},
#  987: {'action': 0, 'preqs': [986], 'robotID': 15},
#  988: {'action': 0, 'preqs': [987], 'robotID': 15},
#  989: {'action': 0, 'preqs': [988], 'robotID': 15},
#  990: {'action': 0, 'preqs': [989], 'robotID': 15},
#  991: {'action': 0, 'preqs': [990], 'robotID': 15},
#  992: {'action': 0, 'preqs': [991], 'robotID': 15},
#  993: {'action': 2, 'preqs': [], 'robotID': 16},
#  994: {'action': 2, 'preqs': [993], 'robotID': 16},
#  995: {'action': 2, 'preqs': [994], 'robotID': 16},
#  996: {'action': 2, 'preqs': [995], 'robotID': 16},
#  997: {'action': 2, 'preqs': [996], 'robotID': 16},
#  998: {'action': 2, 'preqs': [997], 'robotID': 16},
#  999: {'action': 2, 'preqs': [998], 'robotID': 16},
#  1000: {'action': 2, 'preqs': [999], 'robotID': 16},
#  ...}

# %%
with open("/media/marmot-18/Thordak2TB/catkin_ws/src/Tanishq_MAPF/database/pickle_taskList.txt", "w") as f:
    f.write(json.dumps(temp))

# %%
import json
 
# Opening JSON file
with open("/media/marmot-18/Thordak2TB/catkin_ws/src/Tanishq_MAPF/database/pickle_taskList.txt") as f:
    taskList = json.load(f)
