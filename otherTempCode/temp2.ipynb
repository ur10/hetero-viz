# %%
from enum import Enum
import numpy as np
# from usefulFunctions import *
import copy
import  pickle
import json

# %%
class Status(Enum):
    STAGED = 200
    ENQUEUED = 201
    DONE = 202

# %%
class Task:
    # __actionDict__ = {0:np.array([0,0]), 1:np.array([0,1]), 2:np.array([1,0]), 3:np.array([0,-1]), 4:np.array([-1,0])}
    __actionDict__ = {0:np.array([0,0]), 1:np.array([1,0]), 2:np.array([0,1]), 3:np.array([-1,0]), 4:np.array([0,-1])}

    def __init__(self, tid, rid, start, action, time) -> None:
        self.taskID = tid
        self.robotID = rid
        self.action = action
        self.startPos = np.array(start)
        self.goalPos = np.array(self.__actionDict__[action]+start)
        self.time = time
        self.preqs = dict()
        self.status = Status.STAGED
        
    def __checkIfReady__(self):
        # print("Check if ready", self.preqs)
        if self.taskID-1 not in self.preqs:
            temp = list(self.preqs.values())
            if(np.array_equal(temp, np.full_like(temp, Status.DONE.value))):
                return True
            else:
                return False
        if self.preqs[self.taskID-1]>=Status.ENQUEUED.value:
            temp = copy.deepcopy(self.preqs)
            del temp[self.taskID-1]
            temp = list(temp.values())
            if (np.array_equal(temp, np.full_like(temp, Status.DONE.value))):
                return True
            else:
                return False
        return False
    
    def __publishTask__(self):
        global TOPIC
        message = ROS_Task()
        message.taskID = self.taskID
        message.robotID = self.robotID
        message.action = self.action
        message.status = self.status.value

        TOPIC.publish(message)

    
    def __repr__(self) -> str:
        asd = "\n"
        for i in self.__dir__():
            if not i.startswith('__'):
                asd+=i
                asd+=": "
                asd+=str(getattr(self,i))
                asd+=", "

        return asd

class Graph:
    def __init__(self, taskList, startCells) -> None:
        self.currentPositions = copy.deepcopy(startCells)
        self.graph = dict()
        self.taskDict = dict()
        tId = 1
        self.robotList = []
        for rid in range(len(startCells)):
        
            prevTask = None
            for i, task in enumerate(taskList[:,rid]):
                t = Task(tId, rid, self.currentPositions[rid], task, i)
                # print(t)
                self.taskDict[tId] = t
                tId+=1
                self.currentPositions[rid] = t.goalPos
                self.addVertex(t)

                if(prevTask is None):
                    self.robotList.append(t)
                else:
                    self.addEdge(prevTask, t)

                prevTask = t
        # print(taskDict)
        for rid in range(len(startCells)):
            firstTid = self.robotList[rid].taskID
            for taskID in range(firstTid, firstTid+len(taskList)):
                if(taskID not in self.taskDict):
                    continue
                task = self.taskDict[taskID]
                
                for rid_ in range(len(startCells)):
                    if(rid != rid_):
                        # print(rid, rid_)
                        firstTid_ = self.robotList[rid_].taskID
                        for taskID_ in range(firstTid_, firstTid_+len(taskList)):
                            if(taskID_ not in self.taskDict):
                                continue
                            task_ = self.taskDict[taskID_]
                            if np.array_equal(task.startPos, task_.goalPos) and task.time<=task_.time:
                                # print(task, task_)
                                self.addEdge(task, task_)
                                break

            
    
    def addVertex(self, task):
        assert type(task) == Task
        if(task.taskID not in self.graph):
            self.graph[task.taskID] = list()

    def addEdge(self, taskFrom, taskTo):
        assert  type(taskFrom)==Task and taskFrom.taskID in self.graph
        assert type(taskTo)==Task and taskTo.taskID in self.graph
        taskTo.preqs[taskFrom.taskID] = taskFrom.status.value
        self.graph[taskFrom.taskID].append(taskTo.taskID)

    def changeStatus(self, taskID):
        # rospy.loginfo(taskID)
        task = self.taskDict[taskID]
        # print(taskID, task)
        task.status = Status(task.status.value+1)

        task.__publishTask__()

# %%
actionList= np.loadtxt('actions.txt')
actionList = actionList.astype(np.int16)

size = actionList.shape

START=[(2, 7),(20, 1),(17, 16),(2, 0),(10, 1),(16, 22),(17, 7),(1, 4),(5, 5),(17, 18),(7, 22),(21, 20),(7, 1),(1, 2),(15, 21),(2, 17),(5, 10),(17, 13),(10, 22),(2, 21),(8, 4),(8, 19),(5, 3),(20, 3),(14, 12),(19, 20),(1, 7),(2, 14),(14, 21),(15, 2),(11, 21),(17, 1),(2, 10),(5, 9),(1, 5),(13, 1),(22, 2),(15, 14),(3, 21),(2, 8),(1, 0),(22, 16),(0, 14),(21, 2),(8, 22),(18, 8),(18, 1),(0, 20),(1, 22),(17, 5),(11, 8),(17, 11),(8, 17),(0, 9),(16, 0),(17, 2),(4, 8),(14, 19),(2, 11),(12, 14),(8, 6),(21, 1),(2, 16),(21, 17),(0, 18),(19, 22),(20, 16),(9, 2),(0, 17),(7, 8),(1, 6),(11, 0),(17, 3),(0, 0),(9, 14),(22, 10),(8, 9),(21, 16),(21, 15),(1, 1),(20, 15),(19, 1),(9, 22),(22, 3),(2, 9),(7, 21),(14, 13),(0, 21),(12, 8),(0, 2),(18, 20),(17, 22),(1, 10),(0, 10),(5, 4),(22, 5),(13, 8),(2, 22),(5, 15),(6, 14),(1, 13),(5, 19),(22, 7),(0, 12),(15, 22),(21, 19),(5, 20),(10, 8),(21, 7),(22, 0),(7, 2),(1, 16),(11, 19),(14, 8),(8, 5),(1, 19),(1, 11),(0, 5),(1, 20),(8, 7),(5, 18),(14, 6),(22, 21),(14, 17),(6, 2),(18, 14),(15, 20),(12, 22),(21, 12),(6, 8),(0, 7),(11, 17),(22, 20),(0, 11),(11, 6),(14, 2),(2, 3),(16, 2),(14, 10),(0, 13),(16, 1),(15, 1),(21, 21),(18, 21),(0, 4),(5, 22),(20, 6),(1, 9),(20, 14),(12, 0),(0, 8),(20, 5),(20, 13),(12, 2),(13, 22),(1, 3),(21, 10),(11, 3),(4, 1),(17, 21),(20, 18),(14, 3),(14, 14),(0, 6),(7, 14),(22, 8),(8, 1),(2, 19),(12, 1),(20, 4),(18, 0),(1, 17),(5, 1),(22, 18),(19, 0),(22, 9),(9, 8),(17, 17),(2, 12),(21, 8),(8, 21),(20, 19),(5, 11),(17, 10),(17, 6),(22, 14),(3, 20),(11, 15),(3, 2),(8, 3),(17, 15),(13, 21),(18, 22),(14, 1),(21, 3),(6, 0),(8, 8),(14, 11),(21, 13),(11, 1),(10, 20),(22, 13),(5, 13),(6, 21),(0, 22),(3, 22),(0, 16),(3, 14),(4, 14),(1, 15),(5, 14),(8, 15)]

REAL_ROBOT_COUNT = 10
VIRTUAL_ROBOT_COUNT = 30

REAL_ROBOT_START = START[202:]
START = START[:VIRTUAL_ROBOT_COUNT]
START+=REAL_ROBOT_START[:REAL_ROBOT_COUNT]


taskList = np.zeros((size[0], REAL_ROBOT_COUNT+VIRTUAL_ROBOT_COUNT),dtype=np.int16)

for i in range(REAL_ROBOT_COUNT+VIRTUAL_ROBOT_COUNT):
    if i>=VIRTUAL_ROBOT_COUNT:
        taskList[:,i] = actionList[:,202+i-VIRTUAL_ROBOT_COUNT]
    else:
        taskList[:,i] = actionList[:,i]

# %%
GRAPH = Graph(actionList, START)

temp = {}
for i in GRAPH.graph:
    temp[i] = {}
    temp[i]["action"] = int(GRAPH.taskDict[i].action)
    temp[i]["preqs"] = list(GRAPH.taskDict[i].preqs.keys())
    temp[i]["robotID"] = GRAPH.taskDict[i].robotID

with open("/home/mapf/td_ws/src/Tanishq_MAPF/database/tasklist-30-10.txt", "w") as f:
    f.write(json.dumps(temp))


with open("/home/mapf/td_ws/src/Tanishq_MAPF/database/graph-30-10.txt", "w") as f:
    f.write(json.dumps(GRAPH.graph))

# %%
# with open("/home/mapf/td_ws/src/Tanishq_MAPF/database/tasklist-100-10.txt") as f:
#     t = json.load(f)

# with open("/home/mapf/td_ws/src/Tanishq_MAPF/database/graph-100-10.txt") as f:
#     g = json.load(f)

# %%
# G2 = Graph([],[])

# %%
# for i in g:
#     taskID = int(i)
#     G2.graph[taskID] = g[i]
#     t_ = Task(taskID, t[str(taskID)]['robotID'],[-1,-1],t[str(taskID)]['action'],-1)
#     for pre in t[str(taskID)]['preqs']:
#         t_.preqs[pre] = Status.STAGED
#     G2.taskDict[taskID] = t_

# %%
# G2.taskDict
# Out:
# {1:
#  taskID: 1, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {}, status: Status.STAGED, ,
#  2:
#  taskID: 2, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {1: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  3:
#  taskID: 3, robotID: 0, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {2: <Status.STAGED: 200>, 1613: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  4:
#  taskID: 4, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {3: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  5:
#  taskID: 5, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {4: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  6:
#  taskID: 6, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {5: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  7:
#  taskID: 7, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {6: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  8:
#  taskID: 8, robotID: 0, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {7: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  9:
#  taskID: 9, robotID: 0, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {8: <Status.STAGED: 200>, 2419: <Status.STAGED: 200>, 2423: <Status.STAGED: 200>, 3294: <Status.STAGED: 200>, 3600: <Status.STAGED: 200>, 5210: <Status.STAGED: 200>, 5211: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  10:
#  taskID: 10, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {9: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  11:
#  taskID: 11, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {10: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  12:
#  taskID: 12, robotID: 0, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {11: <Status.STAGED: 200>, 2118: <Status.STAGED: 200>, 2119: <Status.STAGED: 200>, 2120: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  13:
#  taskID: 13, robotID: 0, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {12: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  14:
#  taskID: 14, robotID: 0, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {13: <Status.STAGED: 200>, 2424: <Status.STAGED: 200>, 3601: <Status.STAGED: 200>, 5212: <Status.STAGED: 200>, 6709: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  15:
#  taskID: 15, robotID: 0, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {14: <Status.STAGED: 200>, 2425: <Status.STAGED: 200>, 3602: <Status.STAGED: 200>, 5213: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  16:
#  taskID: 16, robotID: 0, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {15: <Status.STAGED: 200>, 2110: <Status.STAGED: 200>, 2111: <Status.STAGED: 200>, 2112: <Status.STAGED: 200>, 2113: <Status.STAGED: 200>, 2426: <Status.STAGED: 200>, 3603: <Status.STAGED: 200>, 5214: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  17:
#  taskID: 17, robotID: 0, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {16: <Status.STAGED: 200>, 1617: <Status.STAGED: 200>, 2427: <Status.STAGED: 200>, 2428: <Status.STAGED: 200>, 2429: <Status.STAGED: 200>, 3604: <Status.STAGED: 200>, 5215: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  18:
#  taskID: 18, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {17: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  19:
#  taskID: 19, robotID: 0, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {18: <Status.STAGED: 200>, 437: <Status.STAGED: 200>, 1618: <Status.STAGED: 200>, 2430: <Status.STAGED: 200>, 2431: <Status.STAGED: 200>, 2432: <Status.STAGED: 200>, 2433: <Status.STAGED: 200>, 2434: <Status.STAGED: 200>, 3605: <Status.STAGED: 200>, 3606: <Status.STAGED: 200>, 3607: <Status.STAGED: 200>, 4345: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  20:
#  taskID: 20, robotID: 0, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {19: <Status.STAGED: 200>, 436: <Status.STAGED: 200>, 4344: <Status.STAGED: 200>, 5217: <Status.STAGED: 200>, 5218: <Status.STAGED: 200>, 5219: <Status.STAGED: 200>, 5220: <Status.STAGED: 200>, 5221: <Status.STAGED: 200>, 5222: <Status.STAGED: 200>, 5223: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  21:
#  taskID: 21, robotID: 0, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {20: <Status.STAGED: 200>, 807: <Status.STAGED: 200>, 808: <Status.STAGED: 200>, 809: <Status.STAGED: 200>, 810: <Status.STAGED: 200>, 811: <Status.STAGED: 200>, 812: <Status.STAGED: 200>, 813: <Status.STAGED: 200>, 4906: <Status.STAGED: 200>, 4907: <Status.STAGED: 200>, 5224: <Status.STAGED: 200>, 5528: <Status.STAGED: 200>, 5529: <Status.STAGED: 200>, 5530: <Status.STAGED: 200>, 5531: <Status.STAGED: 200>, 5532: <Status.STAGED: 200>, 5533: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  22:
#  taskID: 22, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {21: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  23:
#  taskID: 23, robotID: 0, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {22: <Status.STAGED: 200>, 438: <Status.STAGED: 200>, 814: <Status.STAGED: 200>, 1619: <Status.STAGED: 200>, 2435: <Status.STAGED: 200>, 3608: <Status.STAGED: 200>, 3609: <Status.STAGED: 200>, 3610: <Status.STAGED: 200>, 3611: <Status.STAGED: 200>, 4239: <Status.STAGED: 200>, 4346: <Status.STAGED: 200>, 4908: <Status.STAGED: 200>, 4909: <Status.STAGED: 200>, 5534: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  24:
#  taskID: 24, robotID: 0, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {23: <Status.STAGED: 200>, 439: <Status.STAGED: 200>, 815: <Status.STAGED: 200>, 1620: <Status.STAGED: 200>, 2436: <Status.STAGED: 200>, 3612: <Status.STAGED: 200>, 4240: <Status.STAGED: 200>, 4347: <Status.STAGED: 200>, 4355: <Status.STAGED: 200>, 4910: <Status.STAGED: 200>, 4911: <Status.STAGED: 200>, 4912: <Status.STAGED: 200>, 5535: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  25:
#  taskID: 25, robotID: 0, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {24: <Status.STAGED: 200>, 440: <Status.STAGED: 200>, 816: <Status.STAGED: 200>, 817: <Status.STAGED: 200>, 1621: <Status.STAGED: 200>, 3613: <Status.STAGED: 200>, 4241: <Status.STAGED: 200>, 4356: <Status.STAGED: 200>, 4913: <Status.STAGED: 200>, 5536: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  26:
#  taskID: 26, robotID: 0, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {25: <Status.STAGED: 200>, 2440: <Status.STAGED: 200>, 4242: <Status.STAGED: 200>, 4357: <Status.STAGED: 200>, 4358: <Status.STAGED: 200>, 4359: <Status.STAGED: 200>, 4360: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  27:
#  taskID: 27, robotID: 0, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {26: <Status.STAGED: 200>, 2484: <Status.STAGED: 200>, 4243: <Status.STAGED: 200>, 4531: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  28:
#  taskID: 28, robotID: 0, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {27: <Status.STAGED: 200>, 1368: <Status.STAGED: 200>, 2485: <Status.STAGED: 200>, 4244: <Status.STAGED: 200>, 4532: <Status.STAGED: 200>, 5835: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  29:
#  taskID: 29, robotID: 0, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {28: <Status.STAGED: 200>, 80: <Status.STAGED: 200>, 2189: <Status.STAGED: 200>, 2486: <Status.STAGED: 200>, 4245: <Status.STAGED: 200>, 4363: <Status.STAGED: 200>, 4533: <Status.STAGED: 200>, 4919: <Status.STAGED: 200>, 4920: <Status.STAGED: 200>, 5836: <Status.STAGED: 200>, 5848: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  30:
#  taskID: 30, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {29: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  31:
#  taskID: 31, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {30: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  32:
#  taskID: 32, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {31: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  33:
#  taskID: 33, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {32: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  34:
#  taskID: 34, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {33: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  35:
#  taskID: 35, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {34: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  36:
#  taskID: 36, robotID: 0, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {35: <Status.STAGED: 200>, 79: <Status.STAGED: 200>, 263: <Status.STAGED: 200>, 264: <Status.STAGED: 200>, 270: <Status.STAGED: 200>, 746: <Status.STAGED: 200>, 2188: <Status.STAGED: 200>, 2487: <Status.STAGED: 200>, 4246: <Status.STAGED: 200>, 4247: <Status.STAGED: 200>, 4248: <Status.STAGED: 200>, 4364: <Status.STAGED: 200>, 4534: <Status.STAGED: 200>, 4918: <Status.STAGED: 200>, 4921: <Status.STAGED: 200>, 5837: <Status.STAGED: 200>, 5838: <Status.STAGED: 200>, 5839: <Status.STAGED: 200>, 5840: <Status.STAGED: 200>, 5841: <Status.STAGED: 200>, 5842: <Status.STAGED: 200>, 5847: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  37:
#  taskID: 37, robotID: 0, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {36: <Status.STAGED: 200>, 78: <Status.STAGED: 200>, 260: <Status.STAGED: 200>, 261: <Status.STAGED: 200>, 262: <Status.STAGED: 200>, 271: <Status.STAGED: 200>, 747: <Status.STAGED: 200>, 2185: <Status.STAGED: 200>, 2187: <Status.STAGED: 200>, 2488: <Status.STAGED: 200>, 4249: <Status.STAGED: 200>, 4365: <Status.STAGED: 200>, 4535: <Status.STAGED: 200>, 4922: <Status.STAGED: 200>, 6170: <Status.STAGED: 200>, 6172: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  38:
#  taskID: 38, robotID: 0, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {37: <Status.STAGED: 200>, 77: <Status.STAGED: 200>, 1629: <Status.STAGED: 200>, 1630: <Status.STAGED: 200>, 1631: <Status.STAGED: 200>, 1632: <Status.STAGED: 200>, 2183: <Status.STAGED: 200>, 2184: <Status.STAGED: 200>, 2451: <Status.STAGED: 200>, 2489: <Status.STAGED: 200>, 2950: <Status.STAGED: 200>, 4250: <Status.STAGED: 200>, 4309: <Status.STAGED: 200>, 4366: <Status.STAGED: 200>, 4414: <Status.STAGED: 200>, 4536: <Status.STAGED: 200>, 4923: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  39:
#  taskID: 39, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {38: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  40:
#  taskID: 40, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {39: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  41:
#  taskID: 41, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {40: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  42:
#  taskID: 42, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {41: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  43:
#  taskID: 43, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {42: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  44:
#  taskID: 44, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {43: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  45:
#  taskID: 45, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {44: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  46:
#  taskID: 46, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {45: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  47:
#  taskID: 47, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {46: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  48:
#  taskID: 48, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {47: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  49:
#  taskID: 49, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {48: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  50:
#  taskID: 50, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {49: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  51:
#  taskID: 51, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {50: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  52:
#  taskID: 52, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {51: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  53:
#  taskID: 53, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {52: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  54:
#  taskID: 54, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {53: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  55:
#  taskID: 55, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {54: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  56:
#  taskID: 56, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {55: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  57:
#  taskID: 57, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {56: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  58:
#  taskID: 58, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {57: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  59:
#  taskID: 59, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {58: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  60:
#  taskID: 60, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {59: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  61:
#  taskID: 61, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {60: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  62:
#  taskID: 62, robotID: 0, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {61: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  63:
#  taskID: 63, robotID: 1, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {}, status: Status.STAGED, ,
#  64:
#  taskID: 64, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {63: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  65:
#  taskID: 65, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {64: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  66:
#  taskID: 66, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {65: <Status.STAGED: 200>, 2853: <Status.STAGED: 200>, 2854: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  67:
#  taskID: 67, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {66: <Status.STAGED: 200>, 1923: <Status.STAGED: 200>, 1924: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  68:
#  taskID: 68, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {67: <Status.STAGED: 200>, 1802: <Status.STAGED: 200>, 1925: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  69:
#  taskID: 69, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {68: <Status.STAGED: 200>, 1926: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  70:
#  taskID: 70, robotID: 1, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {69: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  71:
#  taskID: 71, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {70: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  72:
#  taskID: 72, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {71: <Status.STAGED: 200>, 4162: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  73:
#  taskID: 73, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {72: <Status.STAGED: 200>, 4163: <Status.STAGED: 200>, 4164: <Status.STAGED: 200>, 4165: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  74:
#  taskID: 74, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {73: <Status.STAGED: 200>, 2491: <Status.STAGED: 200>, 4166: <Status.STAGED: 200>, 4403: <Status.STAGED: 200>, 4404: <Status.STAGED: 200>, 4405: <Status.STAGED: 200>, 4406: <Status.STAGED: 200>, 4407: <Status.STAGED: 200>, 4408: <Status.STAGED: 200>, 4409: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  75:
#  taskID: 75, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {74: <Status.STAGED: 200>, 2182: <Status.STAGED: 200>, 2490: <Status.STAGED: 200>, 4167: <Status.STAGED: 200>, 4413: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  76:
#  taskID: 76, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {75: <Status.STAGED: 200>, 2183: <Status.STAGED: 200>, 2184: <Status.STAGED: 200>, 2489: <Status.STAGED: 200>, 4414: <Status.STAGED: 200>, 4536: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  77:
#  taskID: 77, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {76: <Status.STAGED: 200>, 260: <Status.STAGED: 200>, 261: <Status.STAGED: 200>, 262: <Status.STAGED: 200>, 747: <Status.STAGED: 200>, 2185: <Status.STAGED: 200>, 2488: <Status.STAGED: 200>, 4535: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  78:
#  taskID: 78, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {77: <Status.STAGED: 200>, 263: <Status.STAGED: 200>, 264: <Status.STAGED: 200>, 746: <Status.STAGED: 200>, 2487: <Status.STAGED: 200>, 4534: <Status.STAGED: 200>, 5837: <Status.STAGED: 200>, 5838: <Status.STAGED: 200>, 5839: <Status.STAGED: 200>, 5840: <Status.STAGED: 200>, 5841: <Status.STAGED: 200>, 5842: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  79:
#  taskID: 79, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {78: <Status.STAGED: 200>, 2486: <Status.STAGED: 200>, 4533: <Status.STAGED: 200>, 5836: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  80:
#  taskID: 80, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {79: <Status.STAGED: 200>, 1373: <Status.STAGED: 200>, 1625: <Status.STAGED: 200>, 5833: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  81:
#  taskID: 81, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {80: <Status.STAGED: 200>, 1367: <Status.STAGED: 200>, 1369: <Status.STAGED: 200>, 1374: <Status.STAGED: 200>, 5834: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  82:
#  taskID: 82, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {81: <Status.STAGED: 200>, 441: <Status.STAGED: 200>, 500: <Status.STAGED: 200>, 818: <Status.STAGED: 200>, 1366: <Status.STAGED: 200>, 1370: <Status.STAGED: 200>, 1375: <Status.STAGED: 200>, 1622: <Status.STAGED: 200>, 3614: <Status.STAGED: 200>, 4914: <Status.STAGED: 200>, 5537: <Status.STAGED: 200>, 5831: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  83:
#  taskID: 83, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {82: <Status.STAGED: 200>, 442: <Status.STAGED: 200>, 499: <Status.STAGED: 200>, 1365: <Status.STAGED: 200>, 1376: <Status.STAGED: 200>, 5830: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  84:
#  taskID: 84, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {83: <Status.STAGED: 200>, 443: <Status.STAGED: 200>, 498: <Status.STAGED: 200>, 1377: <Status.STAGED: 200>, 5829: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  85:
#  taskID: 85, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {84: <Status.STAGED: 200>, 444: <Status.STAGED: 200>, 497: <Status.STAGED: 200>, 1378: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  86:
#  taskID: 86, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {85: <Status.STAGED: 200>, 445: <Status.STAGED: 200>, 1379: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  87:
#  taskID: 87, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {86: <Status.STAGED: 200>, 446: <Status.STAGED: 200>, 447: <Status.STAGED: 200>, 1380: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  88:
#  taskID: 88, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {87: <Status.STAGED: 200>, 448: <Status.STAGED: 200>, 1381: <Status.STAGED: 200>, 3299: <Status.STAGED: 200>, 3474: <Status.STAGED: 200>, 4719: <Status.STAGED: 200>, 6705: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  89:
#  taskID: 89, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {88: <Status.STAGED: 200>, 2047: <Status.STAGED: 200>, 3475: <Status.STAGED: 200>, 4720: <Status.STAGED: 200>, 6704: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  90:
#  taskID: 90, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {89: <Status.STAGED: 200>, 993: <Status.STAGED: 200>, 2048: <Status.STAGED: 200>, 3476: <Status.STAGED: 200>, 4721: <Status.STAGED: 200>, 6475: <Status.STAGED: 200>, 6703: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  91:
#  taskID: 91, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {90: <Status.STAGED: 200>, 994: <Status.STAGED: 200>, 2049: <Status.STAGED: 200>, 3477: <Status.STAGED: 200>, 4722: <Status.STAGED: 200>, 6474: <Status.STAGED: 200>, 6700: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  92:
#  taskID: 92, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {91: <Status.STAGED: 200>, 995: <Status.STAGED: 200>, 2050: <Status.STAGED: 200>, 3478: <Status.STAGED: 200>, 4723: <Status.STAGED: 200>, 6473: <Status.STAGED: 200>, 6699: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  93:
#  taskID: 93, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {92: <Status.STAGED: 200>, 996: <Status.STAGED: 200>, 2051: <Status.STAGED: 200>, 3479: <Status.STAGED: 200>, 3480: <Status.STAGED: 200>, 3481: <Status.STAGED: 200>, 3482: <Status.STAGED: 200>, 3483: <Status.STAGED: 200>, 4724: <Status.STAGED: 200>, 6201: <Status.STAGED: 200>, 6202: <Status.STAGED: 200>, 6472: <Status.STAGED: 200>, 6698: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  94:
#  taskID: 94, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {93: <Status.STAGED: 200>, 950: <Status.STAGED: 200>, 956: <Status.STAGED: 200>, 997: <Status.STAGED: 200>, 1075: <Status.STAGED: 200>, 2052: <Status.STAGED: 200>, 2054: <Status.STAGED: 200>, 2623: <Status.STAGED: 200>, 3122: <Status.STAGED: 200>, 3484: <Status.STAGED: 200>, 4725: <Status.STAGED: 200>, 5777: <Status.STAGED: 200>, 6471: <Status.STAGED: 200>, 6574: <Status.STAGED: 200>, 6697: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  95:
#  taskID: 95, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {94: <Status.STAGED: 200>, 949: <Status.STAGED: 200>, 1076: <Status.STAGED: 200>, 2616: <Status.STAGED: 200>, 2617: <Status.STAGED: 200>, 2618: <Status.STAGED: 200>, 2619: <Status.STAGED: 200>, 2620: <Status.STAGED: 200>, 2621: <Status.STAGED: 200>, 2622: <Status.STAGED: 200>, 3123: <Status.STAGED: 200>, 5776: <Status.STAGED: 200>, 6470: <Status.STAGED: 200>, 6573: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  96:
#  taskID: 96, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {95: <Status.STAGED: 200>, 947: <Status.STAGED: 200>, 948: <Status.STAGED: 200>, 1077: <Status.STAGED: 200>, 2615: <Status.STAGED: 200>, 3124: <Status.STAGED: 200>, 3130: <Status.STAGED: 200>, 3131: <Status.STAGED: 200>, 3132: <Status.STAGED: 200>, 3133: <Status.STAGED: 200>, 3856: <Status.STAGED: 200>, 5105: <Status.STAGED: 200>, 5775: <Status.STAGED: 200>, 6469: <Status.STAGED: 200>, 6511: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  97:
#  taskID: 97, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {96: <Status.STAGED: 200>, 946: <Status.STAGED: 200>, 1078: <Status.STAGED: 200>, 1675: <Status.STAGED: 200>, 2373: <Status.STAGED: 200>, 2614: <Status.STAGED: 200>, 2928: <Status.STAGED: 200>, 3125: <Status.STAGED: 200>, 3129: <Status.STAGED: 200>, 3134: <Status.STAGED: 200>, 3855: <Status.STAGED: 200>, 3857: <Status.STAGED: 200>, 5104: <Status.STAGED: 200>, 5106: <Status.STAGED: 200>, 5774: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  98:
#  taskID: 98, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {97: <Status.STAGED: 200>, 942: <Status.STAGED: 200>, 943: <Status.STAGED: 200>, 944: <Status.STAGED: 200>, 945: <Status.STAGED: 200>, 2372: <Status.STAGED: 200>, 3850: <Status.STAGED: 200>, 3851: <Status.STAGED: 200>, 3852: <Status.STAGED: 200>, 3853: <Status.STAGED: 200>, 3854: <Status.STAGED: 200>, 5103: <Status.STAGED: 200>, 6636: <Status.STAGED: 200>, 6638: <Status.STAGED: 200>, 6770: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  99:
#  taskID: 99, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {98: <Status.STAGED: 200>, 939: <Status.STAGED: 200>, 940: <Status.STAGED: 200>, 941: <Status.STAGED: 200>, 2132: <Status.STAGED: 200>, 2371: <Status.STAGED: 200>, 2926: <Status.STAGED: 200>, 6635: <Status.STAGED: 200>, 6639: <Status.STAGED: 200>, 6771: <Status.STAGED: 200>, 6772: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  100:
#  taskID: 100, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {99: <Status.STAGED: 200>, 937: <Status.STAGED: 200>, 938: <Status.STAGED: 200>, 2004: <Status.STAGED: 200>, 2133: <Status.STAGED: 200>, 2139: <Status.STAGED: 200>, 2370: <Status.STAGED: 200>, 2925: <Status.STAGED: 200>, 5101: <Status.STAGED: 200>, 6465: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  101:
#  taskID: 101, robotID: 1, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {100: <Status.STAGED: 200>, 712: <Status.STAGED: 200>, 895: <Status.STAGED: 200>, 1141: <Status.STAGED: 200>, 2003: <Status.STAGED: 200>, 2140: <Status.STAGED: 200>, 4220: <Status.STAGED: 200>, 5722: <Status.STAGED: 200>, 6449: <Status.STAGED: 200>, 6450: <Status.STAGED: 200>, 6451: <Status.STAGED: 200>, 6452: <Status.STAGED: 200>, 6464: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  102:
#  taskID: 102, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {101: <Status.STAGED: 200>, 711: <Status.STAGED: 200>, 894: <Status.STAGED: 200>, 1140: <Status.STAGED: 200>, 2141: <Status.STAGED: 200>, 4217: <Status.STAGED: 200>, 4219: <Status.STAGED: 200>, 5723: <Status.STAGED: 200>, 6518: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  103:
#  taskID: 103, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {102: <Status.STAGED: 200>, 710: <Status.STAGED: 200>, 893: <Status.STAGED: 200>, 1139: <Status.STAGED: 200>, 2142: <Status.STAGED: 200>, 3969: <Status.STAGED: 200>, 4218: <Status.STAGED: 200>, 5724: <Status.STAGED: 200>, 6345: <Status.STAGED: 200>, 6346: <Status.STAGED: 200>, 6347: <Status.STAGED: 200>, 6348: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  104:
#  taskID: 104, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {103: <Status.STAGED: 200>, 709: <Status.STAGED: 200>, 892: <Status.STAGED: 200>, 1138: <Status.STAGED: 200>, 2143: <Status.STAGED: 200>, 2365: <Status.STAGED: 200>, 2920: <Status.STAGED: 200>, 2921: <Status.STAGED: 200>, 6355: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  105:
#  taskID: 105, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {104: <Status.STAGED: 200>, 708: <Status.STAGED: 200>, 891: <Status.STAGED: 200>, 2144: <Status.STAGED: 200>, 2364: <Status.STAGED: 200>, 2915: <Status.STAGED: 200>, 2916: <Status.STAGED: 200>, 2917: <Status.STAGED: 200>, 2918: <Status.STAGED: 200>, 2919: <Status.STAGED: 200>, 3453: <Status.STAGED: 200>, 6107: <Status.STAGED: 200>, 6108: <Status.STAGED: 200>, 6109: <Status.STAGED: 200>, 6110: <Status.STAGED: 200>, 6111: <Status.STAGED: 200>, 6356: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  106:
#  taskID: 106, robotID: 1, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {105: <Status.STAGED: 200>, 890: <Status.STAGED: 200>, 3454: <Status.STAGED: 200>, 5395: <Status.STAGED: 200>, 6326: <Status.STAGED: 200>, 6327: <Status.STAGED: 200>, 6328: <Status.STAGED: 200>, 6357: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  107:
#  taskID: 107, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {106: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  108:
#  taskID: 108, robotID: 1, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {107: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  109:
#  taskID: 109, robotID: 1, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {108: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  110:
#  taskID: 110, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {109: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  111:
#  taskID: 111, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {110: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  112:
#  taskID: 112, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {111: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  113:
#  taskID: 113, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {112: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  114:
#  taskID: 114, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {113: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  115:
#  taskID: 115, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {114: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  116:
#  taskID: 116, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {115: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  117:
#  taskID: 117, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {116: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  118:
#  taskID: 118, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {117: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  119:
#  taskID: 119, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {118: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  120:
#  taskID: 120, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {119: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  121:
#  taskID: 121, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {120: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  122:
#  taskID: 122, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {121: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  123:
#  taskID: 123, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {122: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  124:
#  taskID: 124, robotID: 1, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {123: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  125:
#  taskID: 125, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {}, status: Status.STAGED, ,
#  126:
#  taskID: 126, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {125: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  127:
#  taskID: 127, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {126: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  128:
#  taskID: 128, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {127: <Status.STAGED: 200>, 1057: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  129:
#  taskID: 129, robotID: 2, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {128: <Status.STAGED: 200>, 1058: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  130:
#  taskID: 130, robotID: 2, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {129: <Status.STAGED: 200>, 1059: <Status.STAGED: 200>, 2295: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  131:
#  taskID: 131, robotID: 2, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {130: <Status.STAGED: 200>, 1060: <Status.STAGED: 200>, 2296: <Status.STAGED: 200>, 2297: <Status.STAGED: 200>, 2298: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  132:
#  taskID: 132, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {131: <Status.STAGED: 200>, 5333: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  133:
#  taskID: 133, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {132: <Status.STAGED: 200>, 1489: <Status.STAGED: 200>, 5334: <Status.STAGED: 200>, 5335: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  134:
#  taskID: 134, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {133: <Status.STAGED: 200>, 1490: <Status.STAGED: 200>, 1491: <Status.STAGED: 200>, 5336: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  135:
#  taskID: 135, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {134: <Status.STAGED: 200>, 1492: <Status.STAGED: 200>, 5337: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  136:
#  taskID: 136, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {135: <Status.STAGED: 200>, 1493: <Status.STAGED: 200>, 5338: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  137:
#  taskID: 137, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {136: <Status.STAGED: 200>, 1494: <Status.STAGED: 200>, 5339: <Status.STAGED: 200>, 5459: <Status.STAGED: 200>, 5954: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  138:
#  taskID: 138, robotID: 2, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {137: <Status.STAGED: 200>, 5340: <Status.STAGED: 200>, 5460: <Status.STAGED: 200>, 5955: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  139:
#  taskID: 139, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {138: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  140:
#  taskID: 140, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {139: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  141:
#  taskID: 141, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {140: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  142:
#  taskID: 142, robotID: 2, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {141: <Status.STAGED: 200>, 1504: <Status.STAGED: 200>, 3177: <Status.STAGED: 200>, 6218: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  143:
#  taskID: 143, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {142: <Status.STAGED: 200>, 1495: <Status.STAGED: 200>, 1496: <Status.STAGED: 200>, 1497: <Status.STAGED: 200>, 1498: <Status.STAGED: 200>, 1499: <Status.STAGED: 200>, 1500: <Status.STAGED: 200>, 1501: <Status.STAGED: 200>, 1502: <Status.STAGED: 200>, 1503: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  144:
#  taskID: 144, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {143: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  145:
#  taskID: 145, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {144: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  146:
#  taskID: 146, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {145: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  147:
#  taskID: 147, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {146: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  148:
#  taskID: 148, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {147: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  149:
#  taskID: 149, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {148: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  150:
#  taskID: 150, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {149: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  151:
#  taskID: 151, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {150: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  152:
#  taskID: 152, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {151: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  153:
#  taskID: 153, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {152: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  154:
#  taskID: 154, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {153: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  155:
#  taskID: 155, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {154: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  156:
#  taskID: 156, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {155: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  157:
#  taskID: 157, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {156: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  158:
#  taskID: 158, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {157: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  159:
#  taskID: 159, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {158: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  160:
#  taskID: 160, robotID: 2, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {159: <Status.STAGED: 200>, 404: <Status.STAGED: 200>, 514: <Status.STAGED: 200>, 757: <Status.STAGED: 200>, 760: <Status.STAGED: 200>, 2497: <Status.STAGED: 200>, 2503: <Status.STAGED: 200>, 2504: <Status.STAGED: 200>, 2505: <Status.STAGED: 200>, 2506: <Status.STAGED: 200>, 2823: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  161:
#  taskID: 161, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {160: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  162:
#  taskID: 162, robotID: 2, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {161: <Status.STAGED: 200>, 405: <Status.STAGED: 200>, 513: <Status.STAGED: 200>, 756: <Status.STAGED: 200>, 2175: <Status.STAGED: 200>, 2495: <Status.STAGED: 200>, 2496: <Status.STAGED: 200>, 2824: <Status.STAGED: 200>, 4160: <Status.STAGED: 200>, 4177: <Status.STAGED: 200>, 4182: <Status.STAGED: 200>, 4183: <Status.STAGED: 200>, 4426: <Status.STAGED: 200>, 4427: <Status.STAGED: 200>, 4428: <Status.STAGED: 200>, 4429: <Status.STAGED: 200>, 4437: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  163:
#  taskID: 163, robotID: 2, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {162: <Status.STAGED: 200>, 406: <Status.STAGED: 200>, 511: <Status.STAGED: 200>, 512: <Status.STAGED: 200>, 755: <Status.STAGED: 200>, 2260: <Status.STAGED: 200>, 2494: <Status.STAGED: 200>, 2825: <Status.STAGED: 200>, 4159: <Status.STAGED: 200>, 4178: <Status.STAGED: 200>, 4179: <Status.STAGED: 200>, 4180: <Status.STAGED: 200>, 4181: <Status.STAGED: 200>, 4184: <Status.STAGED: 200>, 4295: <Status.STAGED: 200>, 4296: <Status.STAGED: 200>, 4297: <Status.STAGED: 200>, 4298: <Status.STAGED: 200>, 4299: <Status.STAGED: 200>, 4300: <Status.STAGED: 200>, 4438: <Status.STAGED: 200>, 4439: <Status.STAGED: 200>, 4440: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  164:
#  taskID: 164, robotID: 2, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {163: <Status.STAGED: 200>, 407: <Status.STAGED: 200>, 510: <Status.STAGED: 200>, 754: <Status.STAGED: 200>, 828: <Status.STAGED: 200>, 1246: <Status.STAGED: 200>, 2261: <Status.STAGED: 200>, 2493: <Status.STAGED: 200>, 2826: <Status.STAGED: 200>, 3728: <Status.STAGED: 200>, 4158: <Status.STAGED: 200>, 4185: <Status.STAGED: 200>, 4191: <Status.STAGED: 200>, 4192: <Status.STAGED: 200>, 4193: <Status.STAGED: 200>, 4294: <Status.STAGED: 200>, 4301: <Status.STAGED: 200>, 4609: <Status.STAGED: 200>, 5544: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  165:
#  taskID: 165, robotID: 2, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {164: <Status.STAGED: 200>, 408: <Status.STAGED: 200>, 507: <Status.STAGED: 200>, 508: <Status.STAGED: 200>, 509: <Status.STAGED: 200>, 753: <Status.STAGED: 200>, 824: <Status.STAGED: 200>, 825: <Status.STAGED: 200>, 826: <Status.STAGED: 200>, 827: <Status.STAGED: 200>, 1245: <Status.STAGED: 200>, 2827: <Status.STAGED: 200>, 2828: <Status.STAGED: 200>, 3727: <Status.STAGED: 200>, 4156: <Status.STAGED: 200>, 4157: <Status.STAGED: 200>, 4292: <Status.STAGED: 200>, 4293: <Status.STAGED: 200>, 4302: <Status.STAGED: 200>, 5543: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  166:
#  taskID: 166, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {165: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  167:
#  taskID: 167, robotID: 2, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {166: <Status.STAGED: 200>, 353: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  168:
#  taskID: 168, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {167: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  169:
#  taskID: 169, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {168: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  170:
#  taskID: 170, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {169: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  171:
#  taskID: 171, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {170: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  172:
#  taskID: 172, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {171: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  173:
#  taskID: 173, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {172: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  174:
#  taskID: 174, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {173: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  175:
#  taskID: 175, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {174: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  176:
#  taskID: 176, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {175: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  177:
#  taskID: 177, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {176: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  178:
#  taskID: 178, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {177: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  179:
#  taskID: 179, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {178: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  180:
#  taskID: 180, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {179: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  181:
#  taskID: 181, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {180: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  182:
#  taskID: 182, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {181: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  183:
#  taskID: 183, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {182: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  184:
#  taskID: 184, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {183: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  185:
#  taskID: 185, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {184: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  186:
#  taskID: 186, robotID: 2, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {185: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  187:
#  taskID: 187, robotID: 3, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {}, status: Status.STAGED, ,
#  188:
#  taskID: 188, robotID: 3, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {187: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  189:
#  taskID: 189, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {188: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  190:
#  taskID: 190, robotID: 3, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {189: <Status.STAGED: 200>, 2483: <Status.STAGED: 200>, 4530: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  191:
#  taskID: 191, robotID: 3, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {190: <Status.STAGED: 200>, 2482: <Status.STAGED: 200>, 4529: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  192:
#  taskID: 192, robotID: 3, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {191: <Status.STAGED: 200>, 2481: <Status.STAGED: 200>, 4528: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  193:
#  taskID: 193, robotID: 3, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {192: <Status.STAGED: 200>, 4527: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  194:
#  taskID: 194, robotID: 3, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {193: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  195:
#  taskID: 195, robotID: 3, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {194: <Status.STAGED: 200>, 5519: <Status.STAGED: 200>, 5520: <Status.STAGED: 200>, 5521: <Status.STAGED: 200>, 5522: <Status.STAGED: 200>, 5523: <Status.STAGED: 200>, 5524: <Status.STAGED: 200>, 5525: <Status.STAGED: 200>, 5526: <Status.STAGED: 200>, 5527: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  196:
#  taskID: 196, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {195: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  197:
#  taskID: 197, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {196: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  198:
#  taskID: 198, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {197: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  199:
#  taskID: 199, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {198: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  200:
#  taskID: 200, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {199: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  201:
#  taskID: 201, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {200: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  202:
#  taskID: 202, robotID: 3, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {201: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  203:
#  taskID: 203, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {202: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  204:
#  taskID: 204, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {203: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  205:
#  taskID: 205, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {204: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  206:
#  taskID: 206, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {205: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  207:
#  taskID: 207, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {206: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  208:
#  taskID: 208, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {207: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  209:
#  taskID: 209, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {208: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  210:
#  taskID: 210, robotID: 3, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {209: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  211:
# ...
#  936:
#  taskID: 936, robotID: 15, action: 3, startPos: [-1 -1], goalPos: [-2 -1], time: -1, preqs: {935: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  937:
#  taskID: 937, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {936: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  938:
#  taskID: 938, robotID: 15, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {937: <Status.STAGED: 200>, 6635: <Status.STAGED: 200>, 6639: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  939:
#  taskID: 939, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {938: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  940:
#  taskID: 940, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {939: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  941:
#  taskID: 941, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {940: <Status.STAGED: 200>, 3850: <Status.STAGED: 200>, 3851: <Status.STAGED: 200>, 3852: <Status.STAGED: 200>, 3853: <Status.STAGED: 200>, 3854: <Status.STAGED: 200>, 6636: <Status.STAGED: 200>, 6638: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  942:
#  taskID: 942, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {941: <Status.STAGED: 200>, 6770: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  943:
#  taskID: 943, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {942: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  944:
#  taskID: 944, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {943: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  945:
#  taskID: 945, robotID: 15, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {944: <Status.STAGED: 200>, 1675: <Status.STAGED: 200>, 2614: <Status.STAGED: 200>, 2928: <Status.STAGED: 200>, 3855: <Status.STAGED: 200>, 3857: <Status.STAGED: 200>, 5774: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  946:
#  taskID: 946, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {945: <Status.STAGED: 200>, 2615: <Status.STAGED: 200>, 3856: <Status.STAGED: 200>, 5775: <Status.STAGED: 200>, 6511: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  947:
#  taskID: 947, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {946: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  948:
#  taskID: 948, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {947: <Status.STAGED: 200>, 2616: <Status.STAGED: 200>, 2617: <Status.STAGED: 200>, 2618: <Status.STAGED: 200>, 2619: <Status.STAGED: 200>, 2620: <Status.STAGED: 200>, 2621: <Status.STAGED: 200>, 2622: <Status.STAGED: 200>, 5776: <Status.STAGED: 200>, 6573: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  949:
#  taskID: 949, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {948: <Status.STAGED: 200>, 997: <Status.STAGED: 200>, 2052: <Status.STAGED: 200>, 2054: <Status.STAGED: 200>, 2623: <Status.STAGED: 200>, 3484: <Status.STAGED: 200>, 4725: <Status.STAGED: 200>, 5777: <Status.STAGED: 200>, 6574: <Status.STAGED: 200>, 6697: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  950:
#  taskID: 950, robotID: 15, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {949: <Status.STAGED: 200>, 998: <Status.STAGED: 200>, 2053: <Status.STAGED: 200>, 2624: <Status.STAGED: 200>, 3485: <Status.STAGED: 200>, 4726: <Status.STAGED: 200>, 5778: <Status.STAGED: 200>, 6077: <Status.STAGED: 200>, 6764: <Status.STAGED: 200>, 6765: <Status.STAGED: 200>, 6766: <Status.STAGED: 200>, 6767: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  951:
#  taskID: 951, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {950: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  952:
#  taskID: 952, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {951: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  953:
#  taskID: 953, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {952: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  954:
#  taskID: 954, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {953: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  955:
#  taskID: 955, robotID: 15, action: 4, startPos: [-1 -1], goalPos: [-1 -2], time: -1, preqs: {954: <Status.STAGED: 200>, 1075: <Status.STAGED: 200>, 3122: <Status.STAGED: 200>, 6471: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  956:
#  taskID: 956, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {955: <Status.STAGED: 200>, 1070: <Status.STAGED: 200>, 1071: <Status.STAGED: 200>, 1072: <Status.STAGED: 200>, 1073: <Status.STAGED: 200>, 1074: <Status.STAGED: 200>, 2055: <Status.STAGED: 200>, 3121: <Status.STAGED: 200>, 6139: <Status.STAGED: 200>, 6204: <Status.STAGED: 200>, 6575: <Status.STAGED: 200>, 6576: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  957:
#  taskID: 957, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {956: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  958:
#  taskID: 958, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {957: <Status.STAGED: 200>, 1069: <Status.STAGED: 200>, 2056: <Status.STAGED: 200>, 2057: <Status.STAGED: 200>, 3119: <Status.STAGED: 200>, 3120: <Status.STAGED: 200>, 6140: <Status.STAGED: 200>, 6205: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  959:
#  taskID: 959, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {958: <Status.STAGED: 200>, 460: <Status.STAGED: 200>, 1068: <Status.STAGED: 200>, 1392: <Status.STAGED: 200>, 2058: <Status.STAGED: 200>, 2069: <Status.STAGED: 200>, 3118: <Status.STAGED: 200>, 3311: <Status.STAGED: 200>, 3667: <Status.STAGED: 200>, 4592: <Status.STAGED: 200>, 6141: <Status.STAGED: 200>, 6206: <Status.STAGED: 200>, 6580: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  960:
#  taskID: 960, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {959: <Status.STAGED: 200>, 461: <Status.STAGED: 200>, 1065: <Status.STAGED: 200>, 1066: <Status.STAGED: 200>, 1067: <Status.STAGED: 200>, 1393: <Status.STAGED: 200>, 2070: <Status.STAGED: 200>, 3117: <Status.STAGED: 200>, 3312: <Status.STAGED: 200>, 3665: <Status.STAGED: 200>, 3666: <Status.STAGED: 200>, 4589: <Status.STAGED: 200>, 4590: <Status.STAGED: 200>, 4591: <Status.STAGED: 200>, 6207: <Status.STAGED: 200>, 6581: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  961:
#  taskID: 961, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {960: <Status.STAGED: 200>, 462: <Status.STAGED: 200>, 1064: <Status.STAGED: 200>, 1394: <Status.STAGED: 200>, 2071: <Status.STAGED: 200>, 3116: <Status.STAGED: 200>, 3313: <Status.STAGED: 200>, 3664: <Status.STAGED: 200>, 6208: <Status.STAGED: 200>, 6582: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  962:
#  taskID: 962, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {961: <Status.STAGED: 200>, 463: <Status.STAGED: 200>, 1063: <Status.STAGED: 200>, 1258: <Status.STAGED: 200>, 1395: <Status.STAGED: 200>, 2072: <Status.STAGED: 200>, 2301: <Status.STAGED: 200>, 2317: <Status.STAGED: 200>, 3115: <Status.STAGED: 200>, 3314: <Status.STAGED: 200>, 3663: <Status.STAGED: 200>, 3740: <Status.STAGED: 200>, 6209: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  963:
#  taskID: 963, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {962: <Status.STAGED: 200>, 464: <Status.STAGED: 200>, 1062: <Status.STAGED: 200>, 1259: <Status.STAGED: 200>, 1396: <Status.STAGED: 200>, 2300: <Status.STAGED: 200>, 3659: <Status.STAGED: 200>, 3660: <Status.STAGED: 200>, 3661: <Status.STAGED: 200>, 3662: <Status.STAGED: 200>, 3741: <Status.STAGED: 200>, 6210: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  964:
#  taskID: 964, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {963: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  965:
#  taskID: 965, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {964: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  966:
#  taskID: 966, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {965: <Status.STAGED: 200>, 465: <Status.STAGED: 200>, 1061: <Status.STAGED: 200>, 1260: <Status.STAGED: 200>, 1397: <Status.STAGED: 200>, 1398: <Status.STAGED: 200>, 1399: <Status.STAGED: 200>, 1400: <Status.STAGED: 200>, 2299: <Status.STAGED: 200>, 3742: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  967:
#  taskID: 967, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {966: <Status.STAGED: 200>, 132: <Status.STAGED: 200>, 466: <Status.STAGED: 200>, 1060: <Status.STAGED: 200>, 1261: <Status.STAGED: 200>, 1401: <Status.STAGED: 200>, 1894: <Status.STAGED: 200>, 2296: <Status.STAGED: 200>, 2297: <Status.STAGED: 200>, 2298: <Status.STAGED: 200>, 2885: <Status.STAGED: 200>, 3171: <Status.STAGED: 200>, 3427: <Status.STAGED: 200>, 3743: <Status.STAGED: 200>, 4480: <Status.STAGED: 200>, 5175: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  968:
#  taskID: 968, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {967: <Status.STAGED: 200>, 131: <Status.STAGED: 200>, 1059: <Status.STAGED: 200>, 1402: <Status.STAGED: 200>, 1893: <Status.STAGED: 200>, 2295: <Status.STAGED: 200>, 2883: <Status.STAGED: 200>, 2884: <Status.STAGED: 200>, 3170: <Status.STAGED: 200>, 3426: <Status.STAGED: 200>, 4479: <Status.STAGED: 200>, 5174: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  969:
#  taskID: 969, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {968: <Status.STAGED: 200>, 130: <Status.STAGED: 200>, 1058: <Status.STAGED: 200>, 1403: <Status.STAGED: 200>, 1891: <Status.STAGED: 200>, 1892: <Status.STAGED: 200>, 2882: <Status.STAGED: 200>, 3169: <Status.STAGED: 200>, 3425: <Status.STAGED: 200>, 4478: <Status.STAGED: 200>, 5173: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  970:
#  taskID: 970, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {969: <Status.STAGED: 200>, 129: <Status.STAGED: 200>, 589: <Status.STAGED: 200>, 1057: <Status.STAGED: 200>, 1404: <Status.STAGED: 200>, 1820: <Status.STAGED: 200>, 1890: <Status.STAGED: 200>, 2570: <Status.STAGED: 200>, 2881: <Status.STAGED: 200>, 3048: <Status.STAGED: 200>, 3168: <Status.STAGED: 200>, 3424: <Status.STAGED: 200>, 4477: <Status.STAGED: 200>, 5172: <Status.STAGED: 200>, 5349: <Status.STAGED: 200>, 5964: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  971:
#  taskID: 971, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {970: <Status.STAGED: 200>, 588: <Status.STAGED: 200>, 1888: <Status.STAGED: 200>, 1889: <Status.STAGED: 200>, 2568: <Status.STAGED: 200>, 2569: <Status.STAGED: 200>, 5350: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  972:
#  taskID: 972, robotID: 15, action: 1, startPos: [-1 -1], goalPos: [ 0 -1], time: -1, preqs: {971: <Status.STAGED: 200>, 587: <Status.STAGED: 200>, 1886: <Status.STAGED: 200>, 1887: <Status.STAGED: 200>, 2567: <Status.STAGED: 200>, 5351: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  973:
#  taskID: 973, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {972: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  974:
#  taskID: 974, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {973: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  975:
#  taskID: 975, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {974: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  976:
#  taskID: 976, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {975: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  977:
#  taskID: 977, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {976: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  978:
#  taskID: 978, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {977: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  979:
#  taskID: 979, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {978: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  980:
#  taskID: 980, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {979: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  981:
#  taskID: 981, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {980: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  982:
#  taskID: 982, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {981: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  983:
#  taskID: 983, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {982: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  984:
#  taskID: 984, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {983: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  985:
#  taskID: 985, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {984: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  986:
#  taskID: 986, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {985: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  987:
#  taskID: 987, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {986: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  988:
#  taskID: 988, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {987: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  989:
#  taskID: 989, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {988: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  990:
#  taskID: 990, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {989: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  991:
#  taskID: 991, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {990: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  992:
#  taskID: 992, robotID: 15, action: 0, startPos: [-1 -1], goalPos: [-1 -1], time: -1, preqs: {991: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  993:
#  taskID: 993, robotID: 16, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {}, status: Status.STAGED, ,
#  994:
#  taskID: 994, robotID: 16, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {993: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  995:
#  taskID: 995, robotID: 16, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {994: <Status.STAGED: 200>, 6201: <Status.STAGED: 200>, 6202: <Status.STAGED: 200>, 6698: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  996:
#  taskID: 996, robotID: 16, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {995: <Status.STAGED: 200>, 6574: <Status.STAGED: 200>, 6697: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  997:
#  taskID: 997, robotID: 16, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {996: <Status.STAGED: 200>, 6077: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  998:
#  taskID: 998, robotID: 16, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {997: <Status.STAGED: 200>, 6078: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  999:
#  taskID: 999, robotID: 16, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {998: <Status.STAGED: 200>, 6079: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  1000:
#  taskID: 1000, robotID: 16, action: 2, startPos: [-1 -1], goalPos: [-1  0], time: -1, preqs: {999: <Status.STAGED: 200>, 6080: <Status.STAGED: 200>, 6081: <Status.STAGED: 200>}, status: Status.STAGED, ,
#  ...}
